# %%
import os
import gc
import numpy as np 
import pandas as pd

# %%
pd.options.display.max_rows = 300
pd.options.display.max_columns = 100

# %%
import category_encoders as ce
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split,  KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score

# %%
import lightgbm as lgb

# %%
train = pd.read_csv('application_train.csv', index_col='SK_ID_CURR')
test = pd.read_csv('application_test.csv', index_col='SK_ID_CURR')
test['TARGET'] = 2
traintest = pd.concat([train, test], sort=False).sort_index()

# %%
traintest.head().T
# Out:
# SK_ID_CURR                               100001  \
# TARGET                                        2
# NAME_CONTRACT_TYPE                   Cash loans
# CODE_GENDER                                   F
# FLAG_OWN_CAR                                  N
# FLAG_OWN_REALTY                               Y
# CNT_CHILDREN                                  0
# AMT_INCOME_TOTAL                         135000
# AMT_CREDIT                               568800
# AMT_ANNUITY                             20560.5
# AMT_GOODS_PRICE                          450000
# NAME_TYPE_SUITE                   Unaccompanied
# NAME_INCOME_TYPE                        Working
# NAME_EDUCATION_TYPE            Higher education
# NAME_FAMILY_STATUS                      Married
# NAME_HOUSING_TYPE             House / apartment
# REGION_POPULATION_RELATIVE              0.01885
# DAYS_BIRTH                               -19241
# DAYS_EMPLOYED                             -2329
# DAYS_REGISTRATION                         -5170
# DAYS_ID_PUBLISH                            -812
# OWN_CAR_AGE                                 NaN
# FLAG_MOBIL                                    1
# FLAG_EMP_PHONE                                1
# FLAG_WORK_PHONE                               0
# FLAG_CONT_MOBILE                              1
# FLAG_PHONE                                    0
# FLAG_EMAIL                                    1
# OCCUPATION_TYPE                             NaN
# CNT_FAM_MEMBERS                               2
# REGION_RATING_CLIENT                          2
# REGION_RATING_CLIENT_W_CITY                   2
# WEEKDAY_APPR_PROCESS_START              TUESDAY
# HOUR_APPR_PROCESS_START                      18
# REG_REGION_NOT_LIVE_REGION                    0
# REG_REGION_NOT_WORK_REGION                    0
# LIVE_REGION_NOT_WORK_REGION                   0
# REG_CITY_NOT_LIVE_CITY                        0
# REG_CITY_NOT_WORK_CITY                        0
# LIVE_CITY_NOT_WORK_CITY                       0
# ORGANIZATION_TYPE                  Kindergarten
# EXT_SOURCE_1                           0.752614
# EXT_SOURCE_2                           0.789654
# EXT_SOURCE_3                            0.15952
# APARTMENTS_AVG                            0.066
# BASEMENTAREA_AVG                          0.059
# YEARS_BEGINEXPLUATATION_AVG              0.9732
# YEARS_BUILD_AVG                             NaN
# COMMONAREA_AVG                              NaN
# ELEVATORS_AVG                               NaN
# ENTRANCES_AVG                            0.1379
# FLOORSMAX_AVG                             0.125
# FLOORSMIN_AVG                               NaN
# LANDAREA_AVG                                NaN
# LIVINGAPARTMENTS_AVG                        NaN
# LIVINGAREA_AVG                           0.0505
# NONLIVINGAPARTMENTS_AVG                     NaN
# NONLIVINGAREA_AVG                           NaN
# APARTMENTS_MODE                          0.0672
# BASEMENTAREA_MODE                        0.0612
# YEARS_BEGINEXPLUATATION_MODE             0.9732
# YEARS_BUILD_MODE                            NaN
# COMMONAREA_MODE                             NaN
# ELEVATORS_MODE                              NaN
# ENTRANCES_MODE                           0.1379
# FLOORSMAX_MODE                            0.125
# FLOORSMIN_MODE                              NaN
# LANDAREA_MODE                               NaN
# LIVINGAPARTMENTS_MODE                       NaN
# LIVINGAREA_MODE                          0.0526
# NONLIVINGAPARTMENTS_MODE                    NaN
# NONLIVINGAREA_MODE                          NaN
# APARTMENTS_MEDI                          0.0666
# BASEMENTAREA_MEDI                         0.059
# YEARS_BEGINEXPLUATATION_MEDI             0.9732
# YEARS_BUILD_MEDI                            NaN
# COMMONAREA_MEDI                             NaN
# ELEVATORS_MEDI                              NaN
# ENTRANCES_MEDI                           0.1379
# FLOORSMAX_MEDI                            0.125
# FLOORSMIN_MEDI                              NaN
# LANDAREA_MEDI                               NaN
# LIVINGAPARTMENTS_MEDI                       NaN
# LIVINGAREA_MEDI                          0.0514
# NONLIVINGAPARTMENTS_MEDI                    NaN
# NONLIVINGAREA_MEDI                          NaN
# FONDKAPREMONT_MODE                          NaN
# HOUSETYPE_MODE                   block of flats
# TOTALAREA_MODE                           0.0392
# WALLSMATERIAL_MODE                 Stone, brick
# EMERGENCYSTATE_MODE                          No
# OBS_30_CNT_SOCIAL_CIRCLE                      0
# DEF_30_CNT_SOCIAL_CIRCLE                      0
# OBS_60_CNT_SOCIAL_CIRCLE                      0
# DEF_60_CNT_SOCIAL_CIRCLE                      0
# DAYS_LAST_PHONE_CHANGE                    -1740
# FLAG_DOCUMENT_2                               0
# FLAG_DOCUMENT_3                               1
# FLAG_DOCUMENT_4                               0
# FLAG_DOCUMENT_5                               0
# FLAG_DOCUMENT_6                               0
# FLAG_DOCUMENT_7                               0
# FLAG_DOCUMENT_8                               0
# FLAG_DOCUMENT_9                               0
# FLAG_DOCUMENT_10                              0
# FLAG_DOCUMENT_11                              0
# FLAG_DOCUMENT_12                              0
# FLAG_DOCUMENT_13                              0
# FLAG_DOCUMENT_14                              0
# FLAG_DOCUMENT_15                              0
# FLAG_DOCUMENT_16                              0
# FLAG_DOCUMENT_17                              0
# FLAG_DOCUMENT_18                              0
# FLAG_DOCUMENT_19                              0
# FLAG_DOCUMENT_20                              0
# FLAG_DOCUMENT_21                              0
# AMT_REQ_CREDIT_BUREAU_HOUR                    0
# AMT_REQ_CREDIT_BUREAU_DAY                     0
# AMT_REQ_CREDIT_BUREAU_WEEK                    0
# AMT_REQ_CREDIT_BUREAU_MON                     0
# AMT_REQ_CREDIT_BUREAU_QRT                     0
# AMT_REQ_CREDIT_BUREAU_YEAR                    0
#
# SK_ID_CURR                                           100002  \
# TARGET                                                    1
# NAME_CONTRACT_TYPE                               Cash loans
# CODE_GENDER                                               M
# FLAG_OWN_CAR                                              N
# FLAG_OWN_REALTY                                           Y
# CNT_CHILDREN                                              0
# AMT_INCOME_TOTAL                                     202500
# AMT_CREDIT                                           406598
# AMT_ANNUITY                                         24700.5
# AMT_GOODS_PRICE                                      351000
# NAME_TYPE_SUITE                               Unaccompanied
# NAME_INCOME_TYPE                                    Working
# NAME_EDUCATION_TYPE           Secondary / secondary special
# NAME_FAMILY_STATUS                     Single / not married
# NAME_HOUSING_TYPE                         House / apartment
# REGION_POPULATION_RELATIVE                         0.018801
# DAYS_BIRTH                                            -9461
# DAYS_EMPLOYED                                          -637
# DAYS_REGISTRATION                                     -3648
# DAYS_ID_PUBLISH                                       -2120
# OWN_CAR_AGE                                             NaN
# FLAG_MOBIL                                                1
# FLAG_EMP_PHONE                                            1
# FLAG_WORK_PHONE                                           0
# FLAG_CONT_MOBILE                                          1
# FLAG_PHONE                                                1
# FLAG_EMAIL                                                0
# OCCUPATION_TYPE                                    Laborers
# CNT_FAM_MEMBERS                                           1
# REGION_RATING_CLIENT                                      2
# REGION_RATING_CLIENT_W_CITY                               2
# WEEKDAY_APPR_PROCESS_START                        WEDNESDAY
# HOUR_APPR_PROCESS_START                                  10
# REG_REGION_NOT_LIVE_REGION                                0
# REG_REGION_NOT_WORK_REGION                                0
# LIVE_REGION_NOT_WORK_REGION                               0
# REG_CITY_NOT_LIVE_CITY                                    0
# REG_CITY_NOT_WORK_CITY                                    0
# LIVE_CITY_NOT_WORK_CITY                                   0
# ORGANIZATION_TYPE                    Business Entity Type 3
# EXT_SOURCE_1                                       0.083037
# EXT_SOURCE_2                                       0.262949
# EXT_SOURCE_3                                       0.139376
# APARTMENTS_AVG                                       0.0247
# BASEMENTAREA_AVG                                     0.0369
# YEARS_BEGINEXPLUATATION_AVG                          0.9722
# YEARS_BUILD_AVG                                      0.6192
# COMMONAREA_AVG                                       0.0143
# ELEVATORS_AVG                                             0
# ENTRANCES_AVG                                         0.069
# FLOORSMAX_AVG                                        0.0833
# FLOORSMIN_AVG                                         0.125
# LANDAREA_AVG                                         0.0369
# LIVINGAPARTMENTS_AVG                                 0.0202
# LIVINGAREA_AVG                                        0.019
# NONLIVINGAPARTMENTS_AVG                                   0
# NONLIVINGAREA_AVG                                         0
# APARTMENTS_MODE                                      0.0252
# BASEMENTAREA_MODE                                    0.0383
# YEARS_BEGINEXPLUATATION_MODE                         0.9722
# YEARS_BUILD_MODE                                     0.6341
# COMMONAREA_MODE                                      0.0144
# ELEVATORS_MODE                                            0
# ENTRANCES_MODE                                        0.069
# FLOORSMAX_MODE                                       0.0833
# FLOORSMIN_MODE                                        0.125
# LANDAREA_MODE                                        0.0377
# LIVINGAPARTMENTS_MODE                                 0.022
# LIVINGAREA_MODE                                      0.0198
# NONLIVINGAPARTMENTS_MODE                                  0
# NONLIVINGAREA_MODE                                        0
# APARTMENTS_MEDI                                       0.025
# BASEMENTAREA_MEDI                                    0.0369
# YEARS_BEGINEXPLUATATION_MEDI                         0.9722
# YEARS_BUILD_MEDI                                     0.6243
# COMMONAREA_MEDI                                      0.0144
# ELEVATORS_MEDI                                            0
# ENTRANCES_MEDI                                        0.069
# FLOORSMAX_MEDI                                       0.0833
# FLOORSMIN_MEDI                                        0.125
# LANDAREA_MEDI                                        0.0375
# LIVINGAPARTMENTS_MEDI                                0.0205
# LIVINGAREA_MEDI                                      0.0193
# NONLIVINGAPARTMENTS_MEDI                                  0
# NONLIVINGAREA_MEDI                                        0
# FONDKAPREMONT_MODE                         reg oper account
# HOUSETYPE_MODE                               block of flats
# TOTALAREA_MODE                                       0.0149
# WALLSMATERIAL_MODE                             Stone, brick
# EMERGENCYSTATE_MODE                                      No
# OBS_30_CNT_SOCIAL_CIRCLE                                  2
# DEF_30_CNT_SOCIAL_CIRCLE                                  2
# OBS_60_CNT_SOCIAL_CIRCLE                                  2
# DEF_60_CNT_SOCIAL_CIRCLE                                  2
# DAYS_LAST_PHONE_CHANGE                                -1134
# FLAG_DOCUMENT_2                                           0
# FLAG_DOCUMENT_3                                           1
# FLAG_DOCUMENT_4                                           0
# FLAG_DOCUMENT_5                                           0
# FLAG_DOCUMENT_6                                           0
# FLAG_DOCUMENT_7                                           0
# FLAG_DOCUMENT_8                                           0
# FLAG_DOCUMENT_9                                           0
# FLAG_DOCUMENT_10                                          0
# FLAG_DOCUMENT_11                                          0
# FLAG_DOCUMENT_12                                          0
# FLAG_DOCUMENT_13                                          0
# FLAG_DOCUMENT_14                                          0
# FLAG_DOCUMENT_15                                          0
# FLAG_DOCUMENT_16                                          0
# FLAG_DOCUMENT_17                                          0
# FLAG_DOCUMENT_18                                          0
# FLAG_DOCUMENT_19                                          0
# FLAG_DOCUMENT_20                                          0
# FLAG_DOCUMENT_21                                          0
# AMT_REQ_CREDIT_BUREAU_HOUR                                0
# AMT_REQ_CREDIT_BUREAU_DAY                                 0
# AMT_REQ_CREDIT_BUREAU_WEEK                                0
# AMT_REQ_CREDIT_BUREAU_MON                                 0
# AMT_REQ_CREDIT_BUREAU_QRT                                 0
# AMT_REQ_CREDIT_BUREAU_YEAR                                1
#
# SK_ID_CURR                               100003  \
# TARGET                                        0
# NAME_CONTRACT_TYPE                   Cash loans
# CODE_GENDER                                   F
# FLAG_OWN_CAR                                  N
# FLAG_OWN_REALTY                               N
# CNT_CHILDREN                                  0
# AMT_INCOME_TOTAL                         270000
# AMT_CREDIT                           1.2935e+06
# AMT_ANNUITY                             35698.5
# AMT_GOODS_PRICE                      1.1295e+06
# NAME_TYPE_SUITE                          Family
# NAME_INCOME_TYPE                  State servant
# NAME_EDUCATION_TYPE            Higher education
# NAME_FAMILY_STATUS                      Married
# NAME_HOUSING_TYPE             House / apartment
# REGION_POPULATION_RELATIVE             0.003541
# DAYS_BIRTH                               -16765
# DAYS_EMPLOYED                             -1188
# DAYS_REGISTRATION                         -1186
# DAYS_ID_PUBLISH                            -291
# OWN_CAR_AGE                                 NaN
# FLAG_MOBIL                                    1
# FLAG_EMP_PHONE                                1
# FLAG_WORK_PHONE                               0
# FLAG_CONT_MOBILE                              1
# FLAG_PHONE                                    1
# FLAG_EMAIL                                    0
# OCCUPATION_TYPE                      Core staff
# CNT_FAM_MEMBERS                               2
# REGION_RATING_CLIENT                          1
# REGION_RATING_CLIENT_W_CITY                   1
# WEEKDAY_APPR_PROCESS_START               MONDAY
# HOUR_APPR_PROCESS_START                      11
# REG_REGION_NOT_LIVE_REGION                    0
# REG_REGION_NOT_WORK_REGION                    0
# LIVE_REGION_NOT_WORK_REGION                   0
# REG_CITY_NOT_LIVE_CITY                        0
# REG_CITY_NOT_WORK_CITY                        0
# LIVE_CITY_NOT_WORK_CITY                       0
# ORGANIZATION_TYPE                        School
# EXT_SOURCE_1                           0.311267
# EXT_SOURCE_2                           0.622246
# EXT_SOURCE_3                                NaN
# APARTMENTS_AVG                           0.0959
# BASEMENTAREA_AVG                         0.0529
# YEARS_BEGINEXPLUATATION_AVG              0.9851
# YEARS_BUILD_AVG                           0.796
# COMMONAREA_AVG                           0.0605
# ELEVATORS_AVG                              0.08
# ENTRANCES_AVG                            0.0345
# FLOORSMAX_AVG                            0.2917
# FLOORSMIN_AVG                            0.3333
# LANDAREA_AVG                              0.013
# LIVINGAPARTMENTS_AVG                     0.0773
# LIVINGAREA_AVG                           0.0549
# NONLIVINGAPARTMENTS_AVG                  0.0039
# NONLIVINGAREA_AVG                        0.0098
# APARTMENTS_MODE                          0.0924
# BASEMENTAREA_MODE                        0.0538
# YEARS_BEGINEXPLUATATION_MODE             0.9851
# YEARS_BUILD_MODE                          0.804
# COMMONAREA_MODE                          0.0497
# ELEVATORS_MODE                           0.0806
# ENTRANCES_MODE                           0.0345
# FLOORSMAX_MODE                           0.2917
# FLOORSMIN_MODE                           0.3333
# LANDAREA_MODE                            0.0128
# LIVINGAPARTMENTS_MODE                     0.079
# LIVINGAREA_MODE                          0.0554
# NONLIVINGAPARTMENTS_MODE                      0
# NONLIVINGAREA_MODE                            0
# APARTMENTS_MEDI                          0.0968
# BASEMENTAREA_MEDI                        0.0529
# YEARS_BEGINEXPLUATATION_MEDI             0.9851
# YEARS_BUILD_MEDI                         0.7987
# COMMONAREA_MEDI                          0.0608
# ELEVATORS_MEDI                             0.08
# ENTRANCES_MEDI                           0.0345
# FLOORSMAX_MEDI                           0.2917
# FLOORSMIN_MEDI                           0.3333
# LANDAREA_MEDI                            0.0132
# LIVINGAPARTMENTS_MEDI                    0.0787
# LIVINGAREA_MEDI                          0.0558
# NONLIVINGAPARTMENTS_MEDI                 0.0039
# NONLIVINGAREA_MEDI                         0.01
# FONDKAPREMONT_MODE             reg oper account
# HOUSETYPE_MODE                   block of flats
# TOTALAREA_MODE                           0.0714
# WALLSMATERIAL_MODE                        Block
# EMERGENCYSTATE_MODE                          No
# OBS_30_CNT_SOCIAL_CIRCLE                      1
# DEF_30_CNT_SOCIAL_CIRCLE                      0
# OBS_60_CNT_SOCIAL_CIRCLE                      1
# DEF_60_CNT_SOCIAL_CIRCLE                      0
# DAYS_LAST_PHONE_CHANGE                     -828
# FLAG_DOCUMENT_2                               0
# FLAG_DOCUMENT_3                               1
# FLAG_DOCUMENT_4                               0
# FLAG_DOCUMENT_5                               0
# FLAG_DOCUMENT_6                               0
# FLAG_DOCUMENT_7                               0
# FLAG_DOCUMENT_8                               0
# FLAG_DOCUMENT_9                               0
# FLAG_DOCUMENT_10                              0
# FLAG_DOCUMENT_11                              0
# FLAG_DOCUMENT_12                              0
# FLAG_DOCUMENT_13                              0
# FLAG_DOCUMENT_14                              0
# FLAG_DOCUMENT_15                              0
# FLAG_DOCUMENT_16                              0
# FLAG_DOCUMENT_17                              0
# FLAG_DOCUMENT_18                              0
# FLAG_DOCUMENT_19                              0
# FLAG_DOCUMENT_20                              0
# FLAG_DOCUMENT_21                              0
# AMT_REQ_CREDIT_BUREAU_HOUR                    0
# AMT_REQ_CREDIT_BUREAU_DAY                     0
# AMT_REQ_CREDIT_BUREAU_WEEK                    0
# AMT_REQ_CREDIT_BUREAU_MON                     0
# AMT_REQ_CREDIT_BUREAU_QRT                     0
# AMT_REQ_CREDIT_BUREAU_YEAR                    0
#
# SK_ID_CURR                                           100004  \
# TARGET                                                    0
# NAME_CONTRACT_TYPE                          Revolving loans
# CODE_GENDER                                               M
# FLAG_OWN_CAR                                              Y
# FLAG_OWN_REALTY                                           Y
# CNT_CHILDREN                                              0
# AMT_INCOME_TOTAL                                      67500
# AMT_CREDIT                                           135000
# AMT_ANNUITY                                            6750
# AMT_GOODS_PRICE                                      135000
# NAME_TYPE_SUITE                               Unaccompanied
# NAME_INCOME_TYPE                                    Working
# NAME_EDUCATION_TYPE           Secondary / secondary special
# NAME_FAMILY_STATUS                     Single / not married
# NAME_HOUSING_TYPE                         House / apartment
# REGION_POPULATION_RELATIVE                         0.010032
# DAYS_BIRTH                                           -19046
# DAYS_EMPLOYED                                          -225
# DAYS_REGISTRATION                                     -4260
# DAYS_ID_PUBLISH                                       -2531
# OWN_CAR_AGE                                              26
# FLAG_MOBIL                                                1
# FLAG_EMP_PHONE                                            1
# FLAG_WORK_PHONE                                           1
# FLAG_CONT_MOBILE                                          1
# FLAG_PHONE                                                1
# FLAG_EMAIL                                                0
# OCCUPATION_TYPE                                    Laborers
# CNT_FAM_MEMBERS                                           1
# REGION_RATING_CLIENT                                      2
# REGION_RATING_CLIENT_W_CITY                               2
# WEEKDAY_APPR_PROCESS_START                           MONDAY
# HOUR_APPR_PROCESS_START                                   9
# REG_REGION_NOT_LIVE_REGION                                0
# REG_REGION_NOT_WORK_REGION                                0
# LIVE_REGION_NOT_WORK_REGION                               0
# REG_CITY_NOT_LIVE_CITY                                    0
# REG_CITY_NOT_WORK_CITY                                    0
# LIVE_CITY_NOT_WORK_CITY                                   0
# ORGANIZATION_TYPE                                Government
# EXT_SOURCE_1                                            NaN
# EXT_SOURCE_2                                       0.555912
# EXT_SOURCE_3                                       0.729567
# APARTMENTS_AVG                                          NaN
# BASEMENTAREA_AVG                                        NaN
# YEARS_BEGINEXPLUATATION_AVG                             NaN
# YEARS_BUILD_AVG                                         NaN
# COMMONAREA_AVG                                          NaN
# ELEVATORS_AVG                                           NaN
# ENTRANCES_AVG                                           NaN
# FLOORSMAX_AVG                                           NaN
# FLOORSMIN_AVG                                           NaN
# LANDAREA_AVG                                            NaN
# LIVINGAPARTMENTS_AVG                                    NaN
# LIVINGAREA_AVG                                          NaN
# NONLIVINGAPARTMENTS_AVG                                 NaN
# NONLIVINGAREA_AVG                                       NaN
# APARTMENTS_MODE                                         NaN
# BASEMENTAREA_MODE                                       NaN
# YEARS_BEGINEXPLUATATION_MODE                            NaN
# YEARS_BUILD_MODE                                        NaN
# COMMONAREA_MODE                                         NaN
# ELEVATORS_MODE                                          NaN
# ENTRANCES_MODE                                          NaN
# FLOORSMAX_MODE                                          NaN
# FLOORSMIN_MODE                                          NaN
# LANDAREA_MODE                                           NaN
# LIVINGAPARTMENTS_MODE                                   NaN
# LIVINGAREA_MODE                                         NaN
# NONLIVINGAPARTMENTS_MODE                                NaN
# NONLIVINGAREA_MODE                                      NaN
# APARTMENTS_MEDI                                         NaN
# BASEMENTAREA_MEDI                                       NaN
# YEARS_BEGINEXPLUATATION_MEDI                            NaN
# YEARS_BUILD_MEDI                                        NaN
# COMMONAREA_MEDI                                         NaN
# ELEVATORS_MEDI                                          NaN
# ENTRANCES_MEDI                                          NaN
# FLOORSMAX_MEDI                                          NaN
# FLOORSMIN_MEDI                                          NaN
# LANDAREA_MEDI                                           NaN
# LIVINGAPARTMENTS_MEDI                                   NaN
# LIVINGAREA_MEDI                                         NaN
# NONLIVINGAPARTMENTS_MEDI                                NaN
# NONLIVINGAREA_MEDI                                      NaN
# FONDKAPREMONT_MODE                                      NaN
# HOUSETYPE_MODE                                          NaN
# TOTALAREA_MODE                                          NaN
# WALLSMATERIAL_MODE                                      NaN
# EMERGENCYSTATE_MODE                                     NaN
# OBS_30_CNT_SOCIAL_CIRCLE                                  0
# DEF_30_CNT_SOCIAL_CIRCLE                                  0
# OBS_60_CNT_SOCIAL_CIRCLE                                  0
# DEF_60_CNT_SOCIAL_CIRCLE                                  0
# DAYS_LAST_PHONE_CHANGE                                 -815
# FLAG_DOCUMENT_2                                           0
# FLAG_DOCUMENT_3                                           0
# FLAG_DOCUMENT_4                                           0
# FLAG_DOCUMENT_5                                           0
# FLAG_DOCUMENT_6                                           0
# FLAG_DOCUMENT_7                                           0
# FLAG_DOCUMENT_8                                           0
# FLAG_DOCUMENT_9                                           0
# FLAG_DOCUMENT_10                                          0
# FLAG_DOCUMENT_11                                          0
# FLAG_DOCUMENT_12                                          0
# FLAG_DOCUMENT_13                                          0
# FLAG_DOCUMENT_14                                          0
# FLAG_DOCUMENT_15                                          0
# FLAG_DOCUMENT_16                                          0
# FLAG_DOCUMENT_17                                          0
# FLAG_DOCUMENT_18                                          0
# FLAG_DOCUMENT_19                                          0
# FLAG_DOCUMENT_20                                          0
# FLAG_DOCUMENT_21                                          0
# AMT_REQ_CREDIT_BUREAU_HOUR                                0
# AMT_REQ_CREDIT_BUREAU_DAY                                 0
# AMT_REQ_CREDIT_BUREAU_WEEK                                0
# AMT_REQ_CREDIT_BUREAU_MON                                 0
# AMT_REQ_CREDIT_BUREAU_QRT                                 0
# AMT_REQ_CREDIT_BUREAU_YEAR                                0
#
# SK_ID_CURR                                           100005
# TARGET                                                    2
# NAME_CONTRACT_TYPE                               Cash loans
# CODE_GENDER                                               M
# FLAG_OWN_CAR                                              N
# FLAG_OWN_REALTY                                           Y
# CNT_CHILDREN                                              0
# AMT_INCOME_TOTAL                                      99000
# AMT_CREDIT                                           222768
# AMT_ANNUITY                                           17370
# AMT_GOODS_PRICE                                      180000
# NAME_TYPE_SUITE                               Unaccompanied
# NAME_INCOME_TYPE                                    Working
# NAME_EDUCATION_TYPE           Secondary / secondary special
# NAME_FAMILY_STATUS                                  Married
# NAME_HOUSING_TYPE                         House / apartment
# REGION_POPULATION_RELATIVE                         0.035792
# DAYS_BIRTH                                           -18064
# DAYS_EMPLOYED                                         -4469
# DAYS_REGISTRATION                                     -9118
# DAYS_ID_PUBLISH                                       -1623
# OWN_CAR_AGE                                             NaN
# FLAG_MOBIL                                                1
# FLAG_EMP_PHONE                                            1
# FLAG_WORK_PHONE                                           0
# FLAG_CONT_MOBILE                                          1
# FLAG_PHONE                                                0
# FLAG_EMAIL                                                0
# OCCUPATION_TYPE                          Low-skill Laborers
# CNT_FAM_MEMBERS                                           2
# REGION_RATING_CLIENT                                      2
# REGION_RATING_CLIENT_W_CITY                               2
# WEEKDAY_APPR_PROCESS_START                           FRIDAY
# HOUR_APPR_PROCESS_START                                   9
# REG_REGION_NOT_LIVE_REGION                                0
# REG_REGION_NOT_WORK_REGION                                0
# LIVE_REGION_NOT_WORK_REGION                               0
# REG_CITY_NOT_LIVE_CITY                                    0
# REG_CITY_NOT_WORK_CITY                                    0
# LIVE_CITY_NOT_WORK_CITY                                   0
# ORGANIZATION_TYPE                             Self-employed
# EXT_SOURCE_1                                        0.56499
# EXT_SOURCE_2                                       0.291656
# EXT_SOURCE_3                                       0.432962
# APARTMENTS_AVG                                          NaN
# BASEMENTAREA_AVG                                        NaN
# YEARS_BEGINEXPLUATATION_AVG                             NaN
# YEARS_BUILD_AVG                                         NaN
# COMMONAREA_AVG                                          NaN
# ELEVATORS_AVG                                           NaN
# ENTRANCES_AVG                                           NaN
# FLOORSMAX_AVG                                           NaN
# FLOORSMIN_AVG                                           NaN
# LANDAREA_AVG                                            NaN
# LIVINGAPARTMENTS_AVG                                    NaN
# LIVINGAREA_AVG                                          NaN
# NONLIVINGAPARTMENTS_AVG                                 NaN
# NONLIVINGAREA_AVG                                       NaN
# APARTMENTS_MODE                                         NaN
# BASEMENTAREA_MODE                                       NaN
# YEARS_BEGINEXPLUATATION_MODE                            NaN
# YEARS_BUILD_MODE                                        NaN
# COMMONAREA_MODE                                         NaN
# ELEVATORS_MODE                                          NaN
# ENTRANCES_MODE                                          NaN
# FLOORSMAX_MODE                                          NaN
# FLOORSMIN_MODE                                          NaN
# LANDAREA_MODE                                           NaN
# LIVINGAPARTMENTS_MODE                                   NaN
# LIVINGAREA_MODE                                         NaN
# NONLIVINGAPARTMENTS_MODE                                NaN
# NONLIVINGAREA_MODE                                      NaN
# APARTMENTS_MEDI                                         NaN
# BASEMENTAREA_MEDI                                       NaN
# YEARS_BEGINEXPLUATATION_MEDI                            NaN
# YEARS_BUILD_MEDI                                        NaN
# COMMONAREA_MEDI                                         NaN
# ELEVATORS_MEDI                                          NaN
# ENTRANCES_MEDI                                          NaN
# FLOORSMAX_MEDI                                          NaN
# FLOORSMIN_MEDI                                          NaN
# LANDAREA_MEDI                                           NaN
# LIVINGAPARTMENTS_MEDI                                   NaN
# LIVINGAREA_MEDI                                         NaN
# NONLIVINGAPARTMENTS_MEDI                                NaN
# NONLIVINGAREA_MEDI                                      NaN
# FONDKAPREMONT_MODE                                      NaN
# HOUSETYPE_MODE                                          NaN
# TOTALAREA_MODE                                          NaN
# WALLSMATERIAL_MODE                                      NaN
# EMERGENCYSTATE_MODE                                     NaN
# OBS_30_CNT_SOCIAL_CIRCLE                                  0
# DEF_30_CNT_SOCIAL_CIRCLE                                  0
# OBS_60_CNT_SOCIAL_CIRCLE                                  0
# DEF_60_CNT_SOCIAL_CIRCLE                                  0
# DAYS_LAST_PHONE_CHANGE                                    0
# FLAG_DOCUMENT_2                                           0
# FLAG_DOCUMENT_3                                           1
# FLAG_DOCUMENT_4                                           0
# FLAG_DOCUMENT_5                                           0
# FLAG_DOCUMENT_6                                           0
# FLAG_DOCUMENT_7                                           0
# FLAG_DOCUMENT_8                                           0
# FLAG_DOCUMENT_9                                           0
# FLAG_DOCUMENT_10                                          0
# FLAG_DOCUMENT_11                                          0
# FLAG_DOCUMENT_12                                          0
# FLAG_DOCUMENT_13                                          0
# FLAG_DOCUMENT_14                                          0
# FLAG_DOCUMENT_15                                          0
# FLAG_DOCUMENT_16                                          0
# FLAG_DOCUMENT_17                                          0
# FLAG_DOCUMENT_18                                          0
# FLAG_DOCUMENT_19                                          0
# FLAG_DOCUMENT_20                                          0
# FLAG_DOCUMENT_21                                          0
# AMT_REQ_CREDIT_BUREAU_HOUR                                0
# AMT_REQ_CREDIT_BUREAU_DAY                                 0
# AMT_REQ_CREDIT_BUREAU_WEEK                                0
# AMT_REQ_CREDIT_BUREAU_MON                                 0
# AMT_REQ_CREDIT_BUREAU_QRT                                 0
# AMT_REQ_CREDIT_BUREAU_YEAR                                3

# %%
test.dtypes
numcols = test.select_dtypes(exclude='object').columns.tolist()
numcols.remove('TARGET')
for n in numcols:
    min_ = np.amin(test[n])
    max_ = np.amax(test[n])
    train[n] = train[n].clip(min_, max_)
        
train = train[train.CODE_GENDER != 'XNA']
train = train[train.NAME_INCOME_TYPE != 'Maternity leave']
train = train[train.NAME_FAMILY_STATUS != 'Unknown']
    
traintest = pd.concat([train, test], sort=False).sort_index()
traintest['DAYS_EMPLOYED'].replace(365243, np.nan, inplace=True)
traintest['TT_NULLCOUNT'] = traintest.isnull().sum(axis=1)
del train; del test
gc.collect()
traintest.head().T
# Out:
# SK_ID_CURR                               100001  \
# TARGET                                        2
# NAME_CONTRACT_TYPE                   Cash loans
# CODE_GENDER                                   F
# FLAG_OWN_CAR                                  N
# FLAG_OWN_REALTY                               Y
# CNT_CHILDREN                                  0
# AMT_INCOME_TOTAL                         135000
# AMT_CREDIT                               568800
# AMT_ANNUITY                             20560.5
# AMT_GOODS_PRICE                          450000
# NAME_TYPE_SUITE                   Unaccompanied
# NAME_INCOME_TYPE                        Working
# NAME_EDUCATION_TYPE            Higher education
# NAME_FAMILY_STATUS                      Married
# NAME_HOUSING_TYPE             House / apartment
# REGION_POPULATION_RELATIVE              0.01885
# DAYS_BIRTH                               -19241
# DAYS_EMPLOYED                             -2329
# DAYS_REGISTRATION                         -5170
# DAYS_ID_PUBLISH                            -812
# OWN_CAR_AGE                                 NaN
# FLAG_MOBIL                                    1
# FLAG_EMP_PHONE                                1
# FLAG_WORK_PHONE                               0
# FLAG_CONT_MOBILE                              1
# FLAG_PHONE                                    0
# FLAG_EMAIL                                    1
# OCCUPATION_TYPE                             NaN
# CNT_FAM_MEMBERS                               2
# REGION_RATING_CLIENT                          2
# REGION_RATING_CLIENT_W_CITY                   2
# WEEKDAY_APPR_PROCESS_START              TUESDAY
# HOUR_APPR_PROCESS_START                      18
# REG_REGION_NOT_LIVE_REGION                    0
# REG_REGION_NOT_WORK_REGION                    0
# LIVE_REGION_NOT_WORK_REGION                   0
# REG_CITY_NOT_LIVE_CITY                        0
# REG_CITY_NOT_WORK_CITY                        0
# LIVE_CITY_NOT_WORK_CITY                       0
# ORGANIZATION_TYPE                  Kindergarten
# EXT_SOURCE_1                           0.752614
# EXT_SOURCE_2                           0.789654
# EXT_SOURCE_3                            0.15952
# APARTMENTS_AVG                            0.066
# BASEMENTAREA_AVG                          0.059
# YEARS_BEGINEXPLUATATION_AVG              0.9732
# YEARS_BUILD_AVG                             NaN
# COMMONAREA_AVG                              NaN
# ELEVATORS_AVG                               NaN
# ENTRANCES_AVG                            0.1379
# FLOORSMAX_AVG                             0.125
# FLOORSMIN_AVG                               NaN
# LANDAREA_AVG                                NaN
# LIVINGAPARTMENTS_AVG                        NaN
# LIVINGAREA_AVG                           0.0505
# NONLIVINGAPARTMENTS_AVG                     NaN
# NONLIVINGAREA_AVG                           NaN
# APARTMENTS_MODE                          0.0672
# BASEMENTAREA_MODE                        0.0612
# YEARS_BEGINEXPLUATATION_MODE             0.9732
# YEARS_BUILD_MODE                            NaN
# COMMONAREA_MODE                             NaN
# ELEVATORS_MODE                              NaN
# ENTRANCES_MODE                           0.1379
# FLOORSMAX_MODE                            0.125
# FLOORSMIN_MODE                              NaN
# LANDAREA_MODE                               NaN
# LIVINGAPARTMENTS_MODE                       NaN
# LIVINGAREA_MODE                          0.0526
# NONLIVINGAPARTMENTS_MODE                    NaN
# NONLIVINGAREA_MODE                          NaN
# APARTMENTS_MEDI                          0.0666
# BASEMENTAREA_MEDI                         0.059
# YEARS_BEGINEXPLUATATION_MEDI             0.9732
# YEARS_BUILD_MEDI                            NaN
# COMMONAREA_MEDI                             NaN
# ELEVATORS_MEDI                              NaN
# ENTRANCES_MEDI                           0.1379
# FLOORSMAX_MEDI                            0.125
# FLOORSMIN_MEDI                              NaN
# LANDAREA_MEDI                               NaN
# LIVINGAPARTMENTS_MEDI                       NaN
# LIVINGAREA_MEDI                          0.0514
# NONLIVINGAPARTMENTS_MEDI                    NaN
# NONLIVINGAREA_MEDI                          NaN
# FONDKAPREMONT_MODE                          NaN
# HOUSETYPE_MODE                   block of flats
# TOTALAREA_MODE                           0.0392
# WALLSMATERIAL_MODE                 Stone, brick
# EMERGENCYSTATE_MODE                          No
# OBS_30_CNT_SOCIAL_CIRCLE                      0
# DEF_30_CNT_SOCIAL_CIRCLE                      0
# OBS_60_CNT_SOCIAL_CIRCLE                      0
# DEF_60_CNT_SOCIAL_CIRCLE                      0
# DAYS_LAST_PHONE_CHANGE                    -1740
# FLAG_DOCUMENT_2                               0
# FLAG_DOCUMENT_3                               1
# FLAG_DOCUMENT_4                               0
# FLAG_DOCUMENT_5                               0
# FLAG_DOCUMENT_6                               0
# FLAG_DOCUMENT_7                               0
# FLAG_DOCUMENT_8                               0
# FLAG_DOCUMENT_9                               0
# FLAG_DOCUMENT_10                              0
# FLAG_DOCUMENT_11                              0
# FLAG_DOCUMENT_12                              0
# FLAG_DOCUMENT_13                              0
# FLAG_DOCUMENT_14                              0
# FLAG_DOCUMENT_15                              0
# FLAG_DOCUMENT_16                              0
# FLAG_DOCUMENT_17                              0
# FLAG_DOCUMENT_18                              0
# FLAG_DOCUMENT_19                              0
# FLAG_DOCUMENT_20                              0
# FLAG_DOCUMENT_21                              0
# AMT_REQ_CREDIT_BUREAU_HOUR                    0
# AMT_REQ_CREDIT_BUREAU_DAY                     0
# AMT_REQ_CREDIT_BUREAU_WEEK                    0
# AMT_REQ_CREDIT_BUREAU_MON                     0
# AMT_REQ_CREDIT_BUREAU_QRT                     0
# AMT_REQ_CREDIT_BUREAU_YEAR                    0
# TT_NULLCOUNT                                 27
#
# SK_ID_CURR                                           100002  \
# TARGET                                                    1
# NAME_CONTRACT_TYPE                               Cash loans
# CODE_GENDER                                               M
# FLAG_OWN_CAR                                              N
# FLAG_OWN_REALTY                                           Y
# CNT_CHILDREN                                              0
# AMT_INCOME_TOTAL                                     202500
# AMT_CREDIT                                           406598
# AMT_ANNUITY                                         24700.5
# AMT_GOODS_PRICE                                      351000
# NAME_TYPE_SUITE                               Unaccompanied
# NAME_INCOME_TYPE                                    Working
# NAME_EDUCATION_TYPE           Secondary / secondary special
# NAME_FAMILY_STATUS                     Single / not married
# NAME_HOUSING_TYPE                         House / apartment
# REGION_POPULATION_RELATIVE                         0.018801
# DAYS_BIRTH                                            -9461
# DAYS_EMPLOYED                                          -637
# DAYS_REGISTRATION                                     -3648
# DAYS_ID_PUBLISH                                       -2120
# OWN_CAR_AGE                                             NaN
# FLAG_MOBIL                                                1
# FLAG_EMP_PHONE                                            1
# FLAG_WORK_PHONE                                           0
# FLAG_CONT_MOBILE                                          1
# FLAG_PHONE                                                1
# FLAG_EMAIL                                                0
# OCCUPATION_TYPE                                    Laborers
# CNT_FAM_MEMBERS                                           1
# REGION_RATING_CLIENT                                      2
# REGION_RATING_CLIENT_W_CITY                               2
# WEEKDAY_APPR_PROCESS_START                        WEDNESDAY
# HOUR_APPR_PROCESS_START                                  10
# REG_REGION_NOT_LIVE_REGION                                0
# REG_REGION_NOT_WORK_REGION                                0
# LIVE_REGION_NOT_WORK_REGION                               0
# REG_CITY_NOT_LIVE_CITY                                    0
# REG_CITY_NOT_WORK_CITY                                    0
# LIVE_CITY_NOT_WORK_CITY                                   0
# ORGANIZATION_TYPE                    Business Entity Type 3
# EXT_SOURCE_1                                       0.083037
# EXT_SOURCE_2                                       0.262949
# EXT_SOURCE_3                                       0.139376
# APARTMENTS_AVG                                       0.0247
# BASEMENTAREA_AVG                                     0.0369
# YEARS_BEGINEXPLUATATION_AVG                          0.9722
# YEARS_BUILD_AVG                                      0.6192
# COMMONAREA_AVG                                       0.0143
# ELEVATORS_AVG                                             0
# ENTRANCES_AVG                                         0.069
# FLOORSMAX_AVG                                        0.0833
# FLOORSMIN_AVG                                         0.125
# LANDAREA_AVG                                         0.0369
# LIVINGAPARTMENTS_AVG                                 0.0202
# LIVINGAREA_AVG                                        0.019
# NONLIVINGAPARTMENTS_AVG                                   0
# NONLIVINGAREA_AVG                                         0
# APARTMENTS_MODE                                      0.0252
# BASEMENTAREA_MODE                                    0.0383
# YEARS_BEGINEXPLUATATION_MODE                         0.9722
# YEARS_BUILD_MODE                                     0.6341
# COMMONAREA_MODE                                      0.0144
# ELEVATORS_MODE                                            0
# ENTRANCES_MODE                                        0.069
# FLOORSMAX_MODE                                       0.0833
# FLOORSMIN_MODE                                        0.125
# LANDAREA_MODE                                        0.0377
# LIVINGAPARTMENTS_MODE                                 0.022
# LIVINGAREA_MODE                                      0.0198
# NONLIVINGAPARTMENTS_MODE                                  0
# NONLIVINGAREA_MODE                                        0
# APARTMENTS_MEDI                                       0.025
# BASEMENTAREA_MEDI                                    0.0369
# YEARS_BEGINEXPLUATATION_MEDI                         0.9722
# YEARS_BUILD_MEDI                                     0.6243
# COMMONAREA_MEDI                                      0.0144
# ELEVATORS_MEDI                                            0
# ENTRANCES_MEDI                                        0.069
# FLOORSMAX_MEDI                                       0.0833
# FLOORSMIN_MEDI                                        0.125
# LANDAREA_MEDI                                        0.0375
# LIVINGAPARTMENTS_MEDI                                0.0205
# LIVINGAREA_MEDI                                      0.0193
# NONLIVINGAPARTMENTS_MEDI                                  0
# NONLIVINGAREA_MEDI                                        0
# FONDKAPREMONT_MODE                         reg oper account
# HOUSETYPE_MODE                               block of flats
# TOTALAREA_MODE                                       0.0149
# WALLSMATERIAL_MODE                             Stone, brick
# EMERGENCYSTATE_MODE                                      No
# OBS_30_CNT_SOCIAL_CIRCLE                                  2
# DEF_30_CNT_SOCIAL_CIRCLE                                  2
# OBS_60_CNT_SOCIAL_CIRCLE                                  2
# DEF_60_CNT_SOCIAL_CIRCLE                                  2
# DAYS_LAST_PHONE_CHANGE                                -1134
# FLAG_DOCUMENT_2                                           0
# FLAG_DOCUMENT_3                                           1
# FLAG_DOCUMENT_4                                           0
# FLAG_DOCUMENT_5                                           0
# FLAG_DOCUMENT_6                                           0
# FLAG_DOCUMENT_7                                           0
# FLAG_DOCUMENT_8                                           0
# FLAG_DOCUMENT_9                                           0
# FLAG_DOCUMENT_10                                          0
# FLAG_DOCUMENT_11                                          0
# FLAG_DOCUMENT_12                                          0
# FLAG_DOCUMENT_13                                          0
# FLAG_DOCUMENT_14                                          0
# FLAG_DOCUMENT_15                                          0
# FLAG_DOCUMENT_16                                          0
# FLAG_DOCUMENT_17                                          0
# FLAG_DOCUMENT_18                                          0
# FLAG_DOCUMENT_19                                          0
# FLAG_DOCUMENT_20                                          0
# FLAG_DOCUMENT_21                                          0
# AMT_REQ_CREDIT_BUREAU_HOUR                                0
# AMT_REQ_CREDIT_BUREAU_DAY                                 0
# AMT_REQ_CREDIT_BUREAU_WEEK                                0
# AMT_REQ_CREDIT_BUREAU_MON                                 0
# AMT_REQ_CREDIT_BUREAU_QRT                                 0
# AMT_REQ_CREDIT_BUREAU_YEAR                                1
# TT_NULLCOUNT                                              1
#
# SK_ID_CURR                               100003  \
# TARGET                                        0
# NAME_CONTRACT_TYPE                   Cash loans
# CODE_GENDER                                   F
# FLAG_OWN_CAR                                  N
# FLAG_OWN_REALTY                               N
# CNT_CHILDREN                                  0
# AMT_INCOME_TOTAL                         270000
# AMT_CREDIT                           1.2935e+06
# AMT_ANNUITY                             35698.5
# AMT_GOODS_PRICE                      1.1295e+06
# NAME_TYPE_SUITE                          Family
# NAME_INCOME_TYPE                  State servant
# NAME_EDUCATION_TYPE            Higher education
# NAME_FAMILY_STATUS                      Married
# NAME_HOUSING_TYPE             House / apartment
# REGION_POPULATION_RELATIVE             0.003541
# DAYS_BIRTH                               -16765
# DAYS_EMPLOYED                             -1188
# DAYS_REGISTRATION                         -1186
# DAYS_ID_PUBLISH                            -291
# OWN_CAR_AGE                                 NaN
# FLAG_MOBIL                                    1
# FLAG_EMP_PHONE                                1
# FLAG_WORK_PHONE                               0
# FLAG_CONT_MOBILE                              1
# FLAG_PHONE                                    1
# FLAG_EMAIL                                    0
# OCCUPATION_TYPE                      Core staff
# CNT_FAM_MEMBERS                               2
# REGION_RATING_CLIENT                          1
# REGION_RATING_CLIENT_W_CITY                   1
# WEEKDAY_APPR_PROCESS_START               MONDAY
# HOUR_APPR_PROCESS_START                      11
# REG_REGION_NOT_LIVE_REGION                    0
# REG_REGION_NOT_WORK_REGION                    0
# LIVE_REGION_NOT_WORK_REGION                   0
# REG_CITY_NOT_LIVE_CITY                        0
# REG_CITY_NOT_WORK_CITY                        0
# LIVE_CITY_NOT_WORK_CITY                       0
# ORGANIZATION_TYPE                        School
# EXT_SOURCE_1                           0.311267
# EXT_SOURCE_2                           0.622246
# EXT_SOURCE_3                                NaN
# APARTMENTS_AVG                           0.0959
# BASEMENTAREA_AVG                         0.0529
# YEARS_BEGINEXPLUATATION_AVG              0.9851
# YEARS_BUILD_AVG                           0.796
# COMMONAREA_AVG                           0.0605
# ELEVATORS_AVG                              0.08
# ENTRANCES_AVG                            0.0345
# FLOORSMAX_AVG                            0.2917
# FLOORSMIN_AVG                            0.3333
# LANDAREA_AVG                              0.013
# LIVINGAPARTMENTS_AVG                     0.0773
# LIVINGAREA_AVG                           0.0549
# NONLIVINGAPARTMENTS_AVG                  0.0039
# NONLIVINGAREA_AVG                        0.0098
# APARTMENTS_MODE                          0.0924
# BASEMENTAREA_MODE                        0.0538
# YEARS_BEGINEXPLUATATION_MODE             0.9851
# YEARS_BUILD_MODE                          0.804
# COMMONAREA_MODE                          0.0497
# ELEVATORS_MODE                           0.0806
# ENTRANCES_MODE                           0.0345
# FLOORSMAX_MODE                           0.2917
# FLOORSMIN_MODE                           0.3333
# LANDAREA_MODE                            0.0128
# LIVINGAPARTMENTS_MODE                     0.079
# LIVINGAREA_MODE                          0.0554
# NONLIVINGAPARTMENTS_MODE                      0
# NONLIVINGAREA_MODE                            0
# APARTMENTS_MEDI                          0.0968
# BASEMENTAREA_MEDI                        0.0529
# YEARS_BEGINEXPLUATATION_MEDI             0.9851
# YEARS_BUILD_MEDI                         0.7987
# COMMONAREA_MEDI                          0.0608
# ELEVATORS_MEDI                             0.08
# ENTRANCES_MEDI                           0.0345
# FLOORSMAX_MEDI                           0.2917
# FLOORSMIN_MEDI                           0.3333
# LANDAREA_MEDI                            0.0132
# LIVINGAPARTMENTS_MEDI                    0.0787
# LIVINGAREA_MEDI                          0.0558
# NONLIVINGAPARTMENTS_MEDI                 0.0039
# NONLIVINGAREA_MEDI                         0.01
# FONDKAPREMONT_MODE             reg oper account
# HOUSETYPE_MODE                   block of flats
# TOTALAREA_MODE                           0.0714
# WALLSMATERIAL_MODE                        Block
# EMERGENCYSTATE_MODE                          No
# OBS_30_CNT_SOCIAL_CIRCLE                      1
# DEF_30_CNT_SOCIAL_CIRCLE                      0
# OBS_60_CNT_SOCIAL_CIRCLE                      1
# DEF_60_CNT_SOCIAL_CIRCLE                      0
# DAYS_LAST_PHONE_CHANGE                     -828
# FLAG_DOCUMENT_2                               0
# FLAG_DOCUMENT_3                               1
# FLAG_DOCUMENT_4                               0
# FLAG_DOCUMENT_5                               0
# FLAG_DOCUMENT_6                               0
# FLAG_DOCUMENT_7                               0
# FLAG_DOCUMENT_8                               0
# FLAG_DOCUMENT_9                               0
# FLAG_DOCUMENT_10                              0
# FLAG_DOCUMENT_11                              0
# FLAG_DOCUMENT_12                              0
# FLAG_DOCUMENT_13                              0
# FLAG_DOCUMENT_14                              0
# FLAG_DOCUMENT_15                              0
# FLAG_DOCUMENT_16                              0
# FLAG_DOCUMENT_17                              0
# FLAG_DOCUMENT_18                              0
# FLAG_DOCUMENT_19                              0
# FLAG_DOCUMENT_20                              0
# FLAG_DOCUMENT_21                              0
# AMT_REQ_CREDIT_BUREAU_HOUR                    0
# AMT_REQ_CREDIT_BUREAU_DAY                     0
# AMT_REQ_CREDIT_BUREAU_WEEK                    0
# AMT_REQ_CREDIT_BUREAU_MON                     0
# AMT_REQ_CREDIT_BUREAU_QRT                     0
# AMT_REQ_CREDIT_BUREAU_YEAR                    0
# TT_NULLCOUNT                                  2
#
# SK_ID_CURR                                           100004  \
# TARGET                                                    0
# NAME_CONTRACT_TYPE                          Revolving loans
# CODE_GENDER                                               M
# FLAG_OWN_CAR                                              Y
# FLAG_OWN_REALTY                                           Y
# CNT_CHILDREN                                              0
# AMT_INCOME_TOTAL                                      67500
# AMT_CREDIT                                           135000
# AMT_ANNUITY                                            6750
# AMT_GOODS_PRICE                                      135000
# NAME_TYPE_SUITE                               Unaccompanied
# NAME_INCOME_TYPE                                    Working
# NAME_EDUCATION_TYPE           Secondary / secondary special
# NAME_FAMILY_STATUS                     Single / not married
# NAME_HOUSING_TYPE                         House / apartment
# REGION_POPULATION_RELATIVE                         0.010032
# DAYS_BIRTH                                           -19046
# DAYS_EMPLOYED                                          -225
# DAYS_REGISTRATION                                     -4260
# DAYS_ID_PUBLISH                                       -2531
# OWN_CAR_AGE                                              26
# FLAG_MOBIL                                                1
# FLAG_EMP_PHONE                                            1
# FLAG_WORK_PHONE                                           1
# FLAG_CONT_MOBILE                                          1
# FLAG_PHONE                                                1
# FLAG_EMAIL                                                0
# OCCUPATION_TYPE                                    Laborers
# CNT_FAM_MEMBERS                                           1
# REGION_RATING_CLIENT                                      2
# REGION_RATING_CLIENT_W_CITY                               2
# WEEKDAY_APPR_PROCESS_START                           MONDAY
# HOUR_APPR_PROCESS_START                                   9
# REG_REGION_NOT_LIVE_REGION                                0
# REG_REGION_NOT_WORK_REGION                                0
# LIVE_REGION_NOT_WORK_REGION                               0
# REG_CITY_NOT_LIVE_CITY                                    0
# REG_CITY_NOT_WORK_CITY                                    0
# LIVE_CITY_NOT_WORK_CITY                                   0
# ORGANIZATION_TYPE                                Government
# EXT_SOURCE_1                                            NaN
# EXT_SOURCE_2                                       0.555912
# EXT_SOURCE_3                                       0.729567
# APARTMENTS_AVG                                          NaN
# BASEMENTAREA_AVG                                        NaN
# YEARS_BEGINEXPLUATATION_AVG                             NaN
# YEARS_BUILD_AVG                                         NaN
# COMMONAREA_AVG                                          NaN
# ELEVATORS_AVG                                           NaN
# ENTRANCES_AVG                                           NaN
# FLOORSMAX_AVG                                           NaN
# FLOORSMIN_AVG                                           NaN
# LANDAREA_AVG                                            NaN
# LIVINGAPARTMENTS_AVG                                    NaN
# LIVINGAREA_AVG                                          NaN
# NONLIVINGAPARTMENTS_AVG                                 NaN
# NONLIVINGAREA_AVG                                       NaN
# APARTMENTS_MODE                                         NaN
# BASEMENTAREA_MODE                                       NaN
# YEARS_BEGINEXPLUATATION_MODE                            NaN
# YEARS_BUILD_MODE                                        NaN
# COMMONAREA_MODE                                         NaN
# ELEVATORS_MODE                                          NaN
# ENTRANCES_MODE                                          NaN
# FLOORSMAX_MODE                                          NaN
# FLOORSMIN_MODE                                          NaN
# LANDAREA_MODE                                           NaN
# LIVINGAPARTMENTS_MODE                                   NaN
# LIVINGAREA_MODE                                         NaN
# NONLIVINGAPARTMENTS_MODE                                NaN
# NONLIVINGAREA_MODE                                      NaN
# APARTMENTS_MEDI                                         NaN
# BASEMENTAREA_MEDI                                       NaN
# YEARS_BEGINEXPLUATATION_MEDI                            NaN
# YEARS_BUILD_MEDI                                        NaN
# COMMONAREA_MEDI                                         NaN
# ELEVATORS_MEDI                                          NaN
# ENTRANCES_MEDI                                          NaN
# FLOORSMAX_MEDI                                          NaN
# FLOORSMIN_MEDI                                          NaN
# LANDAREA_MEDI                                           NaN
# LIVINGAPARTMENTS_MEDI                                   NaN
# LIVINGAREA_MEDI                                         NaN
# NONLIVINGAPARTMENTS_MEDI                                NaN
# NONLIVINGAREA_MEDI                                      NaN
# FONDKAPREMONT_MODE                                      NaN
# HOUSETYPE_MODE                                          NaN
# TOTALAREA_MODE                                          NaN
# WALLSMATERIAL_MODE                                      NaN
# EMERGENCYSTATE_MODE                                     NaN
# OBS_30_CNT_SOCIAL_CIRCLE                                  0
# DEF_30_CNT_SOCIAL_CIRCLE                                  0
# OBS_60_CNT_SOCIAL_CIRCLE                                  0
# DEF_60_CNT_SOCIAL_CIRCLE                                  0
# DAYS_LAST_PHONE_CHANGE                                 -815
# FLAG_DOCUMENT_2                                           0
# FLAG_DOCUMENT_3                                           0
# FLAG_DOCUMENT_4                                           0
# FLAG_DOCUMENT_5                                           0
# FLAG_DOCUMENT_6                                           0
# FLAG_DOCUMENT_7                                           0
# FLAG_DOCUMENT_8                                           0
# FLAG_DOCUMENT_9                                           0
# FLAG_DOCUMENT_10                                          0
# FLAG_DOCUMENT_11                                          0
# FLAG_DOCUMENT_12                                          0
# FLAG_DOCUMENT_13                                          0
# FLAG_DOCUMENT_14                                          0
# FLAG_DOCUMENT_15                                          0
# FLAG_DOCUMENT_16                                          0
# FLAG_DOCUMENT_17                                          0
# FLAG_DOCUMENT_18                                          0
# FLAG_DOCUMENT_19                                          0
# FLAG_DOCUMENT_20                                          0
# FLAG_DOCUMENT_21                                          0
# AMT_REQ_CREDIT_BUREAU_HOUR                                0
# AMT_REQ_CREDIT_BUREAU_DAY                                 0
# AMT_REQ_CREDIT_BUREAU_WEEK                                0
# AMT_REQ_CREDIT_BUREAU_MON                                 0
# AMT_REQ_CREDIT_BUREAU_QRT                                 0
# AMT_REQ_CREDIT_BUREAU_YEAR                                0
# TT_NULLCOUNT                                             48
#
# SK_ID_CURR                                           100005
# TARGET                                                    2
# NAME_CONTRACT_TYPE                               Cash loans
# CODE_GENDER                                               M
# FLAG_OWN_CAR                                              N
# FLAG_OWN_REALTY                                           Y
# CNT_CHILDREN                                              0
# AMT_INCOME_TOTAL                                      99000
# AMT_CREDIT                                           222768
# AMT_ANNUITY                                           17370
# AMT_GOODS_PRICE                                      180000
# NAME_TYPE_SUITE                               Unaccompanied
# NAME_INCOME_TYPE                                    Working
# NAME_EDUCATION_TYPE           Secondary / secondary special
# NAME_FAMILY_STATUS                                  Married
# NAME_HOUSING_TYPE                         House / apartment
# REGION_POPULATION_RELATIVE                         0.035792
# DAYS_BIRTH                                           -18064
# DAYS_EMPLOYED                                         -4469
# DAYS_REGISTRATION                                     -9118
# DAYS_ID_PUBLISH                                       -1623
# OWN_CAR_AGE                                             NaN
# FLAG_MOBIL                                                1
# FLAG_EMP_PHONE                                            1
# FLAG_WORK_PHONE                                           0
# FLAG_CONT_MOBILE                                          1
# FLAG_PHONE                                                0
# FLAG_EMAIL                                                0
# OCCUPATION_TYPE                          Low-skill Laborers
# CNT_FAM_MEMBERS                                           2
# REGION_RATING_CLIENT                                      2
# REGION_RATING_CLIENT_W_CITY                               2
# WEEKDAY_APPR_PROCESS_START                           FRIDAY
# HOUR_APPR_PROCESS_START                                   9
# REG_REGION_NOT_LIVE_REGION                                0
# REG_REGION_NOT_WORK_REGION                                0
# LIVE_REGION_NOT_WORK_REGION                               0
# REG_CITY_NOT_LIVE_CITY                                    0
# REG_CITY_NOT_WORK_CITY                                    0
# LIVE_CITY_NOT_WORK_CITY                                   0
# ORGANIZATION_TYPE                             Self-employed
# EXT_SOURCE_1                                        0.56499
# EXT_SOURCE_2                                       0.291656
# EXT_SOURCE_3                                       0.432962
# APARTMENTS_AVG                                          NaN
# BASEMENTAREA_AVG                                        NaN
# YEARS_BEGINEXPLUATATION_AVG                             NaN
# YEARS_BUILD_AVG                                         NaN
# COMMONAREA_AVG                                          NaN
# ELEVATORS_AVG                                           NaN
# ENTRANCES_AVG                                           NaN
# FLOORSMAX_AVG                                           NaN
# FLOORSMIN_AVG                                           NaN
# LANDAREA_AVG                                            NaN
# LIVINGAPARTMENTS_AVG                                    NaN
# LIVINGAREA_AVG                                          NaN
# NONLIVINGAPARTMENTS_AVG                                 NaN
# NONLIVINGAREA_AVG                                       NaN
# APARTMENTS_MODE                                         NaN
# BASEMENTAREA_MODE                                       NaN
# YEARS_BEGINEXPLUATATION_MODE                            NaN
# YEARS_BUILD_MODE                                        NaN
# COMMONAREA_MODE                                         NaN
# ELEVATORS_MODE                                          NaN
# ENTRANCES_MODE                                          NaN
# FLOORSMAX_MODE                                          NaN
# FLOORSMIN_MODE                                          NaN
# LANDAREA_MODE                                           NaN
# LIVINGAPARTMENTS_MODE                                   NaN
# LIVINGAREA_MODE                                         NaN
# NONLIVINGAPARTMENTS_MODE                                NaN
# NONLIVINGAREA_MODE                                      NaN
# APARTMENTS_MEDI                                         NaN
# BASEMENTAREA_MEDI                                       NaN
# YEARS_BEGINEXPLUATATION_MEDI                            NaN
# YEARS_BUILD_MEDI                                        NaN
# COMMONAREA_MEDI                                         NaN
# ELEVATORS_MEDI                                          NaN
# ENTRANCES_MEDI                                          NaN
# FLOORSMAX_MEDI                                          NaN
# FLOORSMIN_MEDI                                          NaN
# LANDAREA_MEDI                                           NaN
# LIVINGAPARTMENTS_MEDI                                   NaN
# LIVINGAREA_MEDI                                         NaN
# NONLIVINGAPARTMENTS_MEDI                                NaN
# NONLIVINGAREA_MEDI                                      NaN
# FONDKAPREMONT_MODE                                      NaN
# HOUSETYPE_MODE                                          NaN
# TOTALAREA_MODE                                          NaN
# WALLSMATERIAL_MODE                                      NaN
# EMERGENCYSTATE_MODE                                     NaN
# OBS_30_CNT_SOCIAL_CIRCLE                                  0
# DEF_30_CNT_SOCIAL_CIRCLE                                  0
# OBS_60_CNT_SOCIAL_CIRCLE                                  0
# DEF_60_CNT_SOCIAL_CIRCLE                                  0
# DAYS_LAST_PHONE_CHANGE                                    0
# FLAG_DOCUMENT_2                                           0
# FLAG_DOCUMENT_3                                           1
# FLAG_DOCUMENT_4                                           0
# FLAG_DOCUMENT_5                                           0
# FLAG_DOCUMENT_6                                           0
# FLAG_DOCUMENT_7                                           0
# FLAG_DOCUMENT_8                                           0
# FLAG_DOCUMENT_9                                           0
# FLAG_DOCUMENT_10                                          0
# FLAG_DOCUMENT_11                                          0
# FLAG_DOCUMENT_12                                          0
# FLAG_DOCUMENT_13                                          0
# FLAG_DOCUMENT_14                                          0
# FLAG_DOCUMENT_15                                          0
# FLAG_DOCUMENT_16                                          0
# FLAG_DOCUMENT_17                                          0
# FLAG_DOCUMENT_18                                          0
# FLAG_DOCUMENT_19                                          0
# FLAG_DOCUMENT_20                                          0
# FLAG_DOCUMENT_21                                          0
# AMT_REQ_CREDIT_BUREAU_HOUR                                0
# AMT_REQ_CREDIT_BUREAU_DAY                                 0
# AMT_REQ_CREDIT_BUREAU_WEEK                                0
# AMT_REQ_CREDIT_BUREAU_MON                                 0
# AMT_REQ_CREDIT_BUREAU_QRT                                 0
# AMT_REQ_CREDIT_BUREAU_YEAR                                3
# TT_NULLCOUNT                                             48

# %%
traintest['HOME_OWNER_TYPE'] = traintest['FLAG_OWN_REALTY'] + traintest['NAME_HOUSING_TYPE']
traintest['OCC_TYPE_GENDER'] = traintest['CODE_GENDER'] + traintest['OCCUPATION_TYPE']
traintest['HOME_OWNER_GENDER'] = traintest['CODE_GENDER'] + traintest['FLAG_OWN_REALTY']

# %%
traintest['ext_sources_mean'] = traintest[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
traintest['ext_sources_std'] = traintest[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)

traintest['annuity_income_percentage'] = traintest['AMT_ANNUITY'] / traintest['AMT_INCOME_TOTAL']
traintest['car_to_birth_ratio'] = traintest['OWN_CAR_AGE'] / traintest['DAYS_BIRTH']
traintest['car_to_employ_ratio'] = traintest['OWN_CAR_AGE'] / traintest['DAYS_EMPLOYED']
traintest['children_ratio'] = traintest['CNT_CHILDREN'] / traintest['CNT_FAM_MEMBERS']
traintest['credit_to_annuity_ratio'] = traintest['AMT_CREDIT'] / traintest['AMT_ANNUITY']
traintest['credit_to_goods_ratio'] = traintest['AMT_CREDIT'] / traintest['AMT_GOODS_PRICE']
traintest['days_employed_percentage'] = traintest['DAYS_EMPLOYED'] / traintest['DAYS_BIRTH']
traintest['income_per_child'] = traintest['AMT_INCOME_TOTAL'] / (1 + traintest['CNT_CHILDREN'])
traintest['income_per_person'] = traintest['AMT_INCOME_TOTAL'] / traintest['CNT_FAM_MEMBERS']
traintest['payment_rate'] = traintest['AMT_ANNUITY'] / traintest['AMT_CREDIT']
traintest['phone_to_birth_ratio'] = traintest['DAYS_LAST_PHONE_CHANGE'] / traintest['DAYS_BIRTH']
traintest['phone_to_employ_ratio'] = traintest['DAYS_LAST_PHONE_CHANGE'] / traintest['DAYS_EMPLOYED']

# %%
traintest['ANNUITY_GROUPED'] = traintest.groupby(['NAME_EDUCATION_TYPE', 'OCCUPATION_TYPE', 'REG_CITY_NOT_WORK_CITY'])['EXT_SOURCE_1'].transform('mean')

# %%
NUMERICAL_COLUMNS = ['AMT_ANNUITY',
                        'AMT_CREDIT',
                        'AMT_INCOME_TOTAL',
                        'AMT_REQ_CREDIT_BUREAU_YEAR',
                        'DAYS_BIRTH',
                        'EXT_SOURCE_1', 
                        'EXT_SOURCE_2',
                        'EXT_SOURCE_3',
                        'AMT_REQ_CREDIT_BUREAU_YEAR'
                        ]

# %%
CAT_COLUMNS =  [['OCCUPATION_TYPE'],
                    ['CODE_GENDER', 'NAME_EDUCATION_TYPE'],
                    ['FLAG_OWN_REALTY', 'NAME_HOUSING_TYPE'],
                    ['CODE_GENDER', 'ORGANIZATION_TYPE'],
                    ['NAME_EDUCATION_TYPE', 'OCCUPATION_TYPE'],
                    ['CODE_GENDER', 'NAME_EDUCATION_TYPE', 'OCCUPATION_TYPE', 'REG_CITY_NOT_WORK_CITY']]

# %%
for agg in ['mean', 'max', 'min']:
    for numcol in NUMERICAL_COLUMNS:
        for catgroup in CAT_COLUMNS:
            traintest[numcol+'_'.join(catgroup)+agg] = traintest.groupby(catgroup)[numcol].transform(agg)

# %%
traintest['previous_employment'] = (traintest['DAYS_EMPLOYED'] > -2000).astype(int)
traintest['retirement_age'] = (traintest['DAYS_BIRTH'] > -14000).astype(int)

# %%
uselesses = ['FLAG_DOCUMENT_10',
                        'FLAG_DOCUMENT_12',
                        'FLAG_DOCUMENT_13',
                        'FLAG_DOCUMENT_14',
                        'FLAG_DOCUMENT_15',
                        'FLAG_DOCUMENT_16',
                        'FLAG_DOCUMENT_17',
                        'FLAG_DOCUMENT_19',
                        'FLAG_DOCUMENT_2',
                        'FLAG_DOCUMENT_20',
                        'FLAG_DOCUMENT_21',
                        'FLAG_DOCUMENT_4',
                        'FLAG_DOCUMENT_7',
                        'FLAG_DOCUMENT_9']

# %%
traintest = traintest.drop(uselesses, axis=1)

# %%
def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df,new_columns

# %%
bureau = pd.read_csv("bureau.csv")
bb = pd.read_csv("bureau_balance.csv")
prev = pd.read_csv('previous_application.csv')
pos = pd.read_csv('POS_CASH_balance.csv')
ins = pd.read_csv('installments_payments.csv')
cc = pd.read_csv('credit_card_balance.csv')

# %%
_, bb_cat = one_hot_encoder(bb, nan_as_category= True)

# %%
bb.head()
# Out:
#    SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0       5715448               0      C
# 1       5715448              -1      C
# 2       5715448              -2      C
# 3       5715448              -3      C
# 4       5715448              -4      C

# %%
bb_cat
# Out:
# ['STATUS_0',
#  'STATUS_1',
#  'STATUS_2',
#  'STATUS_3',
#  'STATUS_4',
#  'STATUS_5',
#  'STATUS_C',
#  'STATUS_X',
#  'STATUS_nan']

# %%
    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size'],
          }
    
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)

# %%
bureau.head()
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
# 1      215354       5714463        Active      currency 1         -208
# 2      215354       5714464        Active      currency 1         -203
# 3      215354       5714465        Active      currency 1         -203
# 4      215354       5714466        Active      currency 1         -629
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0               -153.0             -153.0
# 1                   0               1075.0                NaN
# 2                   0                528.0                NaN
# 3                   0                  NaN                NaN
# 4                   0               1197.0                NaN
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                     NaN                   0         91323.0
# 1                     NaN                   0        225000.0
# 2                     NaN                   0        464323.5
# 3                     NaN                   0         90000.0
# 4                 77674.5                   0       2700000.0
#
#    AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 0                  0.0                   NaN                     0.0
# 1             171342.0                   NaN                     0.0
# 2                  NaN                   NaN                     0.0
# 3                  NaN                   NaN                     0.0
# 4                  NaN                   NaN                     0.0
#
#        CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 0  Consumer credit                -131          NaN
# 1      Credit card                 -20          NaN
# 2  Consumer credit                 -16          NaN
# 3      Credit card                 -16          NaN
# 4  Consumer credit                 -21          NaN

# %%
_, bureau_cat = one_hot_encoder(bureau, nan_as_category= True)

# %%
bureau_cat
# Out:
# ['CREDIT_ACTIVE_Active',
#  'CREDIT_ACTIVE_Bad debt',
#  'CREDIT_ACTIVE_Closed',
#  'CREDIT_ACTIVE_Sold',
#  'CREDIT_ACTIVE_nan',
#  'CREDIT_CURRENCY_currency 1',
#  'CREDIT_CURRENCY_currency 2',
#  'CREDIT_CURRENCY_currency 3',
#  'CREDIT_CURRENCY_currency 4',
#  'CREDIT_CURRENCY_nan',
#  'CREDIT_TYPE_Another type of loan',
#  'CREDIT_TYPE_Car loan',
#  'CREDIT_TYPE_Cash loan (non-earmarked)',
#  'CREDIT_TYPE_Consumer credit',
#  'CREDIT_TYPE_Credit card',
#  'CREDIT_TYPE_Interbank credit',
#  'CREDIT_TYPE_Loan for business development',
#  'CREDIT_TYPE_Loan for purchase of shares (margin lending)',
#  'CREDIT_TYPE_Loan for the purchase of equipment',
#  'CREDIT_TYPE_Loan for working capital replenishment',
#  'CREDIT_TYPE_Microloan',
#  'CREDIT_TYPE_Mobile operator loan',
#  'CREDIT_TYPE_Mortgage',
#  'CREDIT_TYPE_Real estate loan',
#  'CREDIT_TYPE_Unknown type of loan',
#  'CREDIT_TYPE_nan']

# %%
def bureau_and_balance(num_rows = None, nan_as_category = True):
    bb = pd.read_csv("bureau_balance.csv")
    bureau = pd.read_csv("bureau.csv")
    _, bb_cat = one_hot_encoder(bb, nan_as_category= True)
    _, bureau_cat = one_hot_encoder(bureau, nan_as_category= True)
        
    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size'],
          }
    
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)
    bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
    bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)
    del bb, bb_agg
    gc.collect()
        
    num_aggregations = {
            'DAYS_CREDIT': [ 'mean', 'var'],
            'DAYS_CREDIT_ENDDATE': [ 'mean'],
            'DAYS_CREDIT_UPDATE': ['mean'],
            'CREDIT_DAY_OVERDUE': ['mean'],
            'AMT_CREDIT_MAX_OVERDUE': ['mean'],
            'AMT_CREDIT_SUM': [ 'mean', 'sum'],
            'AMT_CREDIT_SUM_DEBT': [ 'mean', 'sum'],
            'AMT_CREDIT_SUM_OVERDUE': ['mean'],
            'AMT_CREDIT_SUM_LIMIT': ['mean', 'sum'],
            'AMT_ANNUITY': ['max', 'mean'],
            'CNT_CREDIT_PROLONG': ['sum'],
        }


    cat_aggregations = {}
    for cat in bureau_cat: cat_aggregations[cat] = ['mean']
    for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']
        
    bureau_agg = bureau.groupby('SK_ID_CURR').agg(num_aggregations ,cat_aggregations)
    bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    # Bureau: Active credits - using only numerical aggregations
    #active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    #active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
    #active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    #bureau_agg = bureau_agg.join(active_agg, how='left', on='SK_ID_CURR')
   # del active, active_agg
    #gc.collect()
    # Bureau: Closed credits - using only numerical aggregations
    #closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    #closed_agg = closed.groupby('SK_ID_CURR').agg(num_aggregations)
    #closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
   # bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
    #del closed, closed_agg, bureau
    #gc.collect()
    return bureau_agg

# %%
def previous_applications(num_rows = None, nan_as_category = True):
    prev = pd.read_csv('previous_application.csv')
    prev, cat_cols = one_hot_encoder(prev, nan_as_category= True)
    # Days 365.243 values -> nan
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # Add feature: value ask / value received percentage
    prev['APP_CREDIT_PERC'] = prev['AMT_APPLICATION'] / prev['AMT_CREDIT']
    # Previous applications numeric features
    num_aggregations = {
            'AMT_ANNUITY': [ 'max', 'mean'],
            'AMT_APPLICATION': ['min', 'mean'],
            'AMT_CREDIT': ['min', 'max', 'mean'],
            'APP_CREDIT_PERC': ['min', 'max', 'mean'],
            'AMT_DOWN_PAYMENT': ['min', 'max', 'mean'],
            'AMT_GOODS_PRICE': ['min', 'max', 'mean'],
            'HOUR_APPR_PROCESS_START': ['min', 'max', 'mean'],
            'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
            'DAYS_DECISION': ['min', 'max', 'mean'],
            'CNT_PAYMENT': ['mean', 'sum'],
        }
    
    cat_aggregations = {}
    for cat in cat_cols:
        cat_aggregations[cat] = ['mean']
        
    prev_agg = prev.groupby('SK_ID_CURR').agg(num_aggregations, cat_aggregations)
    prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])
        
    # Previous Applications: Approved Applications - only numerical features
    approved = prev[prev['NAME_CONTRACT_STATUS_Approved'] == 1]
    approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
    approved_agg.columns = pd.Index(['APPROVED_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
    prev_agg = prev_agg.join(approved_agg, how='left', on='SK_ID_CURR')
        
    # Previous Applications: Refused Applications - only numerical features
    refused = prev[prev['NAME_CONTRACT_STATUS_Refused'] == 1]
    refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
    refused_agg.columns = pd.Index(['REFUSED_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
    prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
    del refused, refused_agg, approved, approved_agg, prev
    gc.collect()
    return prev_agg

# %%
    def pos_cash(num_rows = None, nan_as_category = True):
        pos = pd.read_csv('POS_CASH_balance.csv')
        pos, cat_cols = one_hot_encoder(pos, nan_as_category= True)
        
        # Features
        aggregations = {
            'MONTHS_BALANCE': ['max', 'mean', 'size'],
            'SK_DPD': ['max', 'mean'],
            'SK_DPD_DEF': ['max', 'mean']
        }
        for cat in cat_cols:
            aggregations[cat] = ['mean']
        
        pos_agg = pos.groupby('SK_ID_CURR').agg(aggregations)
        pos_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in pos_agg.columns.tolist()])
        
        # Count pos cash accounts
        pos_agg['POS_COUNT'] = pos.groupby('SK_ID_CURR').size()
        del pos
        gc.collect()
        return pos_agg

# %%
    def installments_payments(num_rows = None, nan_as_category = True):
        ins = pd.read_csv('installments_payments.csv')
        ins, cat_cols = one_hot_encoder(ins, nan_as_category= True)
        
        # Percentage and difference paid in each installment (amount paid and installment value)
        ins['PAYMENT_PERC'] = ins['AMT_PAYMENT'] / ins['AMT_INSTALMENT']
        ins['PAYMENT_DIFF'] = ins['AMT_INSTALMENT'] - ins['AMT_PAYMENT']
        
        # Days past due and days before due (no negative values)
        ins['DPD'] = ins['DAYS_ENTRY_PAYMENT'] - ins['DAYS_INSTALMENT']
        ins['DBD'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
        ins['DPD'] = ins['DPD'].apply(lambda x: x if x > 0 else 0)
        ins['DBD'] = ins['DBD'].apply(lambda x: x if x > 0 else 0)
        
        # Features: Perform aggregations
        aggregations = {
            'NUM_INSTALMENT_VERSION': ['nunique'],
            'DPD': ['max', 'mean', 'sum'],
            'DBD': ['max', 'mean', 'sum'],
            'PAYMENT_PERC': [ 'mean', 'sum', 'var'],
            'PAYMENT_DIFF': [ 'mean', 'sum', 'var'],
            'AMT_INSTALMENT': ['max', 'mean', 'sum'],
            'AMT_PAYMENT': ['min', 'max', 'mean', 'sum'],
            'DAYS_ENTRY_PAYMENT': ['max', 'mean', 'sum']
        }
        for cat in cat_cols:
            aggregations[cat] = ['mean']
        ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
        ins_agg.columns = pd.Index(['INSTAL_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
        
        # Count installments accounts
        ins_agg['INSTAL_COUNT'] = ins.groupby('SK_ID_CURR').size()
        del ins
        gc.collect()
        return ins_agg

# %%
    def credit_card_balance(num_rows = None, nan_as_category = True):
        cc = pd.read_csv('credit_card_balance.csv')
        cc, cat_cols = one_hot_encoder(cc, nan_as_category= True)
        
        # General aggregations
        cc.drop(['SK_ID_PREV'], axis= 1, inplace = True)
        cc_agg = cc.groupby('SK_ID_CURR').agg(['min', 'max', 'mean', 'sum', 'var'])
        cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
        
        # Count credit card lines
        cc_agg['CC_COUNT'] = cc.groupby('SK_ID_CURR').size()
        del cc
        gc.collect()
        return cc_agg

# %%
    bureau = bureau_and_balance()
    traintest = traintest.join(bureau)
    del bureau
    print('bureau segment done')
# Out:
# bureau segment done

# %%
    prev = previous_applications()
    traintest = traintest.join(prev)
    del prev
    print('prev segment done')

    pos = pos_cash()
    traintest = traintest.join(pos)
    del pos
    print('pos segment done')

    ins = installments_payments()
    traintest = traintest.join(ins)
    del ins
    print('ins segment done')

    cc = credit_card_balance()
    traintest = traintest.join(cc)
    del cc
    print('cc segment done')

traintest.shape
# Out:
# prev segment done
# pos segment done
# ins segment done
# cc segment done
# (356244, 552)

# %%
    objcols = traintest.select_dtypes('object')
    for c in objcols.columns:
        traintest[c] = traintest[c].astype('str')
        traintest[c] = LabelEncoder().fit_transform(traintest[c])
        if traintest[c].nunique() < 50:
            traintest[c] = traintest[c].astype('category')

    train = traintest[traintest.TARGET != 2]
    test = traintest[traintest.TARGET == 2]

    train.dtypes[train.dtypes=='category'] ####
    train.select_dtypes('category').dtypes ####
    print(train.shape, test.shape)

    X = train.drop('TARGET', axis=1)
    y = train['TARGET']
    X_test = test.drop('TARGET', axis=1)

    del(traintest)
    gc.collect()

train.head().T
# Out:
# ((307500, 552), (48744, 552))
# SK_ID_CURR                                             100002      100003  \
# TARGET                                                      1           0
# NAME_CONTRACT_TYPE                                          0           0
# CODE_GENDER                                                 1           0
# FLAG_OWN_CAR                                                0           0
# FLAG_OWN_REALTY                                             1           0
# CNT_CHILDREN                                                0           0
# AMT_INCOME_TOTAL                                       202500      270000
# AMT_CREDIT                                             406598  1.2935e+06
# AMT_ANNUITY                                           24700.5     35698.5
# AMT_GOODS_PRICE                                        351000  1.1295e+06
# NAME_TYPE_SUITE                                             6           1
# NAME_INCOME_TYPE                                            6           3
# NAME_EDUCATION_TYPE                                         4           1
# NAME_FAMILY_STATUS                                          3           1
# NAME_HOUSING_TYPE                                           1           1
# REGION_POPULATION_RELATIVE                           0.018801    0.003541
# DAYS_BIRTH                                              -9461      -16765
# DAYS_EMPLOYED                                            -637       -1188
# DAYS_REGISTRATION                                       -3648       -1186
# DAYS_ID_PUBLISH                                         -2120        -291
# OWN_CAR_AGE                                               NaN         NaN
# FLAG_MOBIL                                                  1           1
# FLAG_EMP_PHONE                                              1           1
# FLAG_WORK_PHONE                                             0           0
# FLAG_CONT_MOBILE                                            1           1
# FLAG_PHONE                                                  1           1
# FLAG_EMAIL                                                  0           0
# OCCUPATION_TYPE                                             8           3
# CNT_FAM_MEMBERS                                             1           2
# REGION_RATING_CLIENT                                        2           1
# REGION_RATING_CLIENT_W_CITY                                 2           1
# WEEKDAY_APPR_PROCESS_START                                  6           1
# HOUR_APPR_PROCESS_START                                    10          11
# REG_REGION_NOT_LIVE_REGION                                  0           0
# REG_REGION_NOT_WORK_REGION                                  0           0
# LIVE_REGION_NOT_WORK_REGION                                 0           0
# REG_CITY_NOT_LIVE_CITY                                      0           0
# REG_CITY_NOT_WORK_CITY                                      0           0
# LIVE_CITY_NOT_WORK_CITY                                     0           0
# ORGANIZATION_TYPE                                           5          39
# EXT_SOURCE_1                                         0.083037    0.311267
# EXT_SOURCE_2                                         0.262949    0.622246
# EXT_SOURCE_3                                         0.139376         NaN
# APARTMENTS_AVG                                         0.0247      0.0959
# BASEMENTAREA_AVG                                       0.0369      0.0529
# YEARS_BEGINEXPLUATATION_AVG                            0.9722      0.9851
# YEARS_BUILD_AVG                                        0.6192       0.796
# COMMONAREA_AVG                                         0.0143      0.0605
# ELEVATORS_AVG                                               0        0.08
# ENTRANCES_AVG                                           0.069      0.0345
# FLOORSMAX_AVG                                          0.0833      0.2917
# FLOORSMIN_AVG                                           0.125      0.3333
# LANDAREA_AVG                                           0.0369       0.013
# LIVINGAPARTMENTS_AVG                                   0.0202      0.0773
# LIVINGAREA_AVG                                          0.019      0.0549
# NONLIVINGAPARTMENTS_AVG                                     0      0.0039
# NONLIVINGAREA_AVG                                           0      0.0098
# APARTMENTS_MODE                                        0.0252      0.0924
# BASEMENTAREA_MODE                                      0.0383      0.0538
# YEARS_BEGINEXPLUATATION_MODE                           0.9722      0.9851
# YEARS_BUILD_MODE                                       0.6341       0.804
# COMMONAREA_MODE                                        0.0144      0.0497
# ELEVATORS_MODE                                              0      0.0806
# ENTRANCES_MODE                                          0.069      0.0345
# FLOORSMAX_MODE                                         0.0833      0.2917
# FLOORSMIN_MODE                                          0.125      0.3333
# LANDAREA_MODE                                          0.0377      0.0128
# LIVINGAPARTMENTS_MODE                                   0.022       0.079
# LIVINGAREA_MODE                                        0.0198      0.0554
# NONLIVINGAPARTMENTS_MODE                                    0           0
# NONLIVINGAREA_MODE                                          0           0
# APARTMENTS_MEDI                                         0.025      0.0968
# BASEMENTAREA_MEDI                                      0.0369      0.0529
# YEARS_BEGINEXPLUATATION_MEDI                           0.9722      0.9851
# YEARS_BUILD_MEDI                                       0.6243      0.7987
# COMMONAREA_MEDI                                        0.0144      0.0608
# ELEVATORS_MEDI                                              0        0.08
# ENTRANCES_MEDI                                          0.069      0.0345
# FLOORSMAX_MEDI                                         0.0833      0.2917
# FLOORSMIN_MEDI                                          0.125      0.3333
# LANDAREA_MEDI                                          0.0375      0.0132
# LIVINGAPARTMENTS_MEDI                                  0.0205      0.0787
# LIVINGAREA_MEDI                                        0.0193      0.0558
# NONLIVINGAPARTMENTS_MEDI                                    0      0.0039
# NONLIVINGAREA_MEDI                                          0        0.01
# FONDKAPREMONT_MODE                                          3           3
# HOUSETYPE_MODE                                              0           0
# TOTALAREA_MODE                                         0.0149      0.0714
# WALLSMATERIAL_MODE                                          5           0
# EMERGENCYSTATE_MODE                                         0           0
# OBS_30_CNT_SOCIAL_CIRCLE                                    2           1
# DEF_30_CNT_SOCIAL_CIRCLE                                    2           0
# OBS_60_CNT_SOCIAL_CIRCLE                                    2           1
# DEF_60_CNT_SOCIAL_CIRCLE                                    2           0
# DAYS_LAST_PHONE_CHANGE                                  -1134        -828
# FLAG_DOCUMENT_3                                             1           1
# FLAG_DOCUMENT_5                                             0           0
# FLAG_DOCUMENT_6                                             0           0
# FLAG_DOCUMENT_8                                             0           0
# FLAG_DOCUMENT_11                                            0           0
# FLAG_DOCUMENT_18                                            0           0
# AMT_REQ_CREDIT_BUREAU_HOUR                                  0           0
# AMT_REQ_CREDIT_BUREAU_DAY                                   0           0
# AMT_REQ_CREDIT_BUREAU_WEEK                                  0           0
# AMT_REQ_CREDIT_BUREAU_MON                                   0           0
# AMT_REQ_CREDIT_BUREAU_QRT                                   0           0
# AMT_REQ_CREDIT_BUREAU_YEAR                                  1           0
# TT_NULLCOUNT                                                1           2
# HOME_OWNER_TYPE                                             7           1
# OCC_TYPE_GENDER                                            26           3
# HOME_OWNER_GENDER                                           3           0
# ext_sources_mean                                     0.161787    0.466757
# ext_sources_std                                     0.0920258    0.219895
# annuity_income_percentage                            0.121978    0.132217
# car_to_birth_ratio                                        NaN         NaN
# car_to_employ_ratio                                       NaN         NaN
# children_ratio                                              0           0
# credit_to_annuity_ratio                               16.4611     36.2341
# credit_to_goods_ratio                                  1.1584      1.1452
# days_employed_percentage                             0.067329   0.0708619
# income_per_child                                       202500      270000
# income_per_person                                      202500      135000
# payment_rate                                        0.0607493   0.0275983
# phone_to_birth_ratio                                  0.11986   0.0493886
# phone_to_employ_ratio                                 1.78022     0.69697
# ANNUITY_GROUPED                                      0.438877    0.553024
# AMT_ANNUITYOCCUPATION_TYPEmean                        26698.5     27886.5
# AMT_ANNUITYCODE_GENDER_NAME_EDUCATION_TYPEmean        27736.3     30360.2
# AMT_ANNUITYFLAG_OWN_REALTY_NAME_HOUSING_TYPEmean      27445.6     27844.3
# AMT_ANNUITYCODE_GENDER_ORGANIZATION_TYPEmean          30177.6       26873
# AMT_ANNUITYNAME_EDUCATION_TYPE_OCCUPATION_TYPEmean    26442.7     29690.5
# AMT_ANNUITYCODE_GENDER_NAME_EDUCATION_TYPE_OCCU...    27330.7     29517.8
# AMT_CREDITOCCUPATION_TYPEmean                          556548      613692
# AMT_CREDITCODE_GENDER_NAME_EDUCATION_TYPEmean          567925      670355
# AMT_CREDITFLAG_OWN_REALTY_NAME_HOUSING_TYPEmean        580990      625964
# AMT_CREDITCODE_GENDER_ORGANIZATION_TYPEmean            611094      616884
# AMT_CREDITNAME_EDUCATION_TYPE_OCCUPATION_TYPEmean      552190      660720
# AMT_CREDITCODE_GENDER_NAME_EDUCATION_TYPE_OCCUP...     559693      666057
# AMT_INCOME_TOTALOCCUPATION_TYPEmean                    165261      173926
# AMT_INCOME_TOTALCODE_GENDER_NAME_EDUCATION_TYPE...     177597      192605
# AMT_INCOME_TOTALFLAG_OWN_REALTY_NAME_HOUSING_TY...     170037      170165
# AMT_INCOME_TOTALCODE_GENDER_ORGANIZATION_TYPEmean      208795      155194
# AMT_INCOME_TOTALNAME_EDUCATION_TYPE_OCCUPATION_...     162113      192789
# AMT_INCOME_TOTALCODE_GENDER_NAME_EDUCATION_TYPE...     174063      182974
# AMT_REQ_CREDIT_BUREAU_YEAROCCUPATION_TYPEmean         1.91487     1.70121
# AMT_REQ_CREDIT_BUREAU_YEARCODE_GENDER_NAME_EDUC...    1.92237     1.70913
# AMT_REQ_CREDIT_BUREAU_YEARFLAG_OWN_REALTY_NAME_...    1.99506     1.71353
# AMT_REQ_CREDIT_BUREAU_YEARCODE_GENDER_ORGANIZAT...    1.89983     1.75962
# AMT_REQ_CREDIT_BUREAU_YEARNAME_EDUCATION_TYPE_O...    1.93352     1.58537
# AMT_REQ_CREDIT_BUREAU_YEARCODE_GENDER_NAME_EDUC...    1.90451     1.60847
# ...                                                       ...         ...
# INSTAL_PAYMENT_DIFF_SUM                                     0           0
# INSTAL_PAYMENT_DIFF_VAR                                     0           0
# INSTAL_DBD_MAX                                             31          14
# INSTAL_DBD_MEAN                                       20.4211        7.16
# INSTAL_DBD_SUM                                            388         179
# INSTAL_PAYMENT_PERC_MEAN                                    1           1
# INSTAL_PAYMENT_PERC_SUM                                    19          25
# INSTAL_PAYMENT_PERC_VAR                                     0           0
# INSTAL_COUNT                                               19          25
# CC_MONTHS_BALANCE_MIN                                     NaN         NaN
# CC_MONTHS_BALANCE_MAX                                     NaN         NaN
# CC_MONTHS_BALANCE_MEAN                                    NaN         NaN
# CC_MONTHS_BALANCE_SUM                                     NaN         NaN
# CC_MONTHS_BALANCE_VAR                                     NaN         NaN
# CC_AMT_BALANCE_MIN                                        NaN         NaN
# CC_AMT_BALANCE_MAX                                        NaN         NaN
# CC_AMT_BALANCE_MEAN                                       NaN         NaN
# CC_AMT_BALANCE_SUM                                        NaN         NaN
# CC_AMT_BALANCE_VAR                                        NaN         NaN
# CC_AMT_CREDIT_LIMIT_ACTUAL_MIN                            NaN         NaN
# CC_AMT_CREDIT_LIMIT_ACTUAL_MAX                            NaN         NaN
# CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN                           NaN         NaN
# CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                            NaN         NaN
# CC_AMT_CREDIT_LIMIT_ACTUAL_VAR                            NaN         NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_MIN                           NaN         NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_MAX                           NaN         NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_MEAN                          NaN         NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_SUM                           NaN         NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_VAR                           NaN         NaN
# CC_AMT_DRAWINGS_CURRENT_MIN                               NaN         NaN
# CC_AMT_DRAWINGS_CURRENT_MAX                               NaN         NaN
# CC_AMT_DRAWINGS_CURRENT_MEAN                              NaN         NaN
# CC_AMT_DRAWINGS_CURRENT_SUM                               NaN         NaN
# CC_AMT_DRAWINGS_CURRENT_VAR                               NaN         NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_MIN                         NaN         NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_MAX                         NaN         NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN                        NaN         NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_SUM                         NaN         NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_VAR                         NaN         NaN
# CC_AMT_DRAWINGS_POS_CURRENT_MIN                           NaN         NaN
# CC_AMT_DRAWINGS_POS_CURRENT_MAX                           NaN         NaN
# CC_AMT_DRAWINGS_POS_CURRENT_MEAN                          NaN         NaN
# CC_AMT_DRAWINGS_POS_CURRENT_SUM                           NaN         NaN
# CC_AMT_DRAWINGS_POS_CURRENT_VAR                           NaN         NaN
# CC_AMT_INST_MIN_REGULARITY_MIN                            NaN         NaN
# CC_AMT_INST_MIN_REGULARITY_MAX                            NaN         NaN
# CC_AMT_INST_MIN_REGULARITY_MEAN                           NaN         NaN
# CC_AMT_INST_MIN_REGULARITY_SUM                            NaN         NaN
# CC_AMT_INST_MIN_REGULARITY_VAR                            NaN         NaN
# CC_AMT_PAYMENT_CURRENT_MIN                                NaN         NaN
# CC_AMT_PAYMENT_CURRENT_MAX                                NaN         NaN
# CC_AMT_PAYMENT_CURRENT_MEAN                               NaN         NaN
# CC_AMT_PAYMENT_CURRENT_SUM                                NaN         NaN
# CC_AMT_PAYMENT_CURRENT_VAR                                NaN         NaN
# CC_AMT_PAYMENT_TOTAL_CURRENT_MIN                          NaN         NaN
# CC_AMT_PAYMENT_TOTAL_CURRENT_MAX                          NaN         NaN
# CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN                         NaN         NaN
# CC_AMT_PAYMENT_TOTAL_CURRENT_SUM                          NaN         NaN
# CC_AMT_PAYMENT_TOTAL_CURRENT_VAR                          NaN         NaN
# CC_AMT_RECEIVABLE_PRINCIPAL_MIN                           NaN         NaN
# CC_AMT_RECEIVABLE_PRINCIPAL_MAX                           NaN         NaN
# CC_AMT_RECEIVABLE_PRINCIPAL_MEAN                          NaN         NaN
# CC_AMT_RECEIVABLE_PRINCIPAL_SUM                           NaN         NaN
# CC_AMT_RECEIVABLE_PRINCIPAL_VAR                           NaN         NaN
# CC_AMT_RECIVABLE_MIN                                      NaN         NaN
# CC_AMT_RECIVABLE_MAX                                      NaN         NaN
# CC_AMT_RECIVABLE_MEAN                                     NaN         NaN
# CC_AMT_RECIVABLE_SUM                                      NaN         NaN
# CC_AMT_RECIVABLE_VAR                                      NaN         NaN
# CC_AMT_TOTAL_RECEIVABLE_MIN                               NaN         NaN
# CC_AMT_TOTAL_RECEIVABLE_MAX                               NaN         NaN
# CC_AMT_TOTAL_RECEIVABLE_MEAN                              NaN         NaN
# CC_AMT_TOTAL_RECEIVABLE_SUM                               NaN         NaN
# CC_AMT_TOTAL_RECEIVABLE_VAR                               NaN         NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_MIN                           NaN         NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_MAX                           NaN         NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_MEAN                          NaN         NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_SUM                           NaN         NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_VAR                           NaN         NaN
# CC_CNT_DRAWINGS_CURRENT_MIN                               NaN         NaN
# CC_CNT_DRAWINGS_CURRENT_MAX                               NaN         NaN
# CC_CNT_DRAWINGS_CURRENT_MEAN                              NaN         NaN
# CC_CNT_DRAWINGS_CURRENT_SUM                               NaN         NaN
# CC_CNT_DRAWINGS_CURRENT_VAR                               NaN         NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_MIN                         NaN         NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_MAX                         NaN         NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN                        NaN         NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_SUM                         NaN         NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_VAR                         NaN         NaN
# CC_CNT_DRAWINGS_POS_CURRENT_MIN                           NaN         NaN
# CC_CNT_DRAWINGS_POS_CURRENT_MAX                           NaN         NaN
# CC_CNT_DRAWINGS_POS_CURRENT_MEAN                          NaN         NaN
# CC_CNT_DRAWINGS_POS_CURRENT_SUM                           NaN         NaN
# CC_CNT_DRAWINGS_POS_CURRENT_VAR                           NaN         NaN
# CC_CNT_INSTALMENT_MATURE_CUM_MIN                          NaN         NaN
# CC_CNT_INSTALMENT_MATURE_CUM_MAX                          NaN         NaN
# CC_CNT_INSTALMENT_MATURE_CUM_MEAN                         NaN         NaN
# CC_CNT_INSTALMENT_MATURE_CUM_SUM                          NaN         NaN
# CC_CNT_INSTALMENT_MATURE_CUM_VAR                          NaN         NaN
# CC_SK_DPD_MIN                                             NaN         NaN
# CC_SK_DPD_MAX                                             NaN         NaN
# CC_SK_DPD_MEAN                                            NaN         NaN
# CC_SK_DPD_SUM                                             NaN         NaN
# CC_SK_DPD_VAR                                             NaN         NaN
# CC_SK_DPD_DEF_MIN                                         NaN         NaN
# CC_SK_DPD_DEF_MAX                                         NaN         NaN
# CC_SK_DPD_DEF_MEAN                                        NaN         NaN
# CC_SK_DPD_DEF_SUM                                         NaN         NaN
# CC_SK_DPD_DEF_VAR                                         NaN         NaN
# CC_NAME_CONTRACT_STATUS_Active_MIN                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_Active_MAX                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_Active_MEAN                       NaN         NaN
# CC_NAME_CONTRACT_STATUS_Active_SUM                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_Active_VAR                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_Approved_MIN                      NaN         NaN
# CC_NAME_CONTRACT_STATUS_Approved_MAX                      NaN         NaN
# CC_NAME_CONTRACT_STATUS_Approved_MEAN                     NaN         NaN
# CC_NAME_CONTRACT_STATUS_Approved_SUM                      NaN         NaN
# CC_NAME_CONTRACT_STATUS_Approved_VAR                      NaN         NaN
# CC_NAME_CONTRACT_STATUS_Completed_MIN                     NaN         NaN
# CC_NAME_CONTRACT_STATUS_Completed_MAX                     NaN         NaN
# CC_NAME_CONTRACT_STATUS_Completed_MEAN                    NaN         NaN
# CC_NAME_CONTRACT_STATUS_Completed_SUM                     NaN         NaN
# CC_NAME_CONTRACT_STATUS_Completed_VAR                     NaN         NaN
# CC_NAME_CONTRACT_STATUS_Demand_MIN                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_Demand_MAX                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_Demand_MEAN                       NaN         NaN
# CC_NAME_CONTRACT_STATUS_Demand_SUM                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_Demand_VAR                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_Refused_MIN                       NaN         NaN
# CC_NAME_CONTRACT_STATUS_Refused_MAX                       NaN         NaN
# CC_NAME_CONTRACT_STATUS_Refused_MEAN                      NaN         NaN
# CC_NAME_CONTRACT_STATUS_Refused_SUM                       NaN         NaN
# CC_NAME_CONTRACT_STATUS_Refused_VAR                       NaN         NaN
# CC_NAME_CONTRACT_STATUS_Sent proposal_MIN                 NaN         NaN
# CC_NAME_CONTRACT_STATUS_Sent proposal_MAX                 NaN         NaN
# CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN                NaN         NaN
# CC_NAME_CONTRACT_STATUS_Sent proposal_SUM                 NaN         NaN
# CC_NAME_CONTRACT_STATUS_Sent proposal_VAR                 NaN         NaN
# CC_NAME_CONTRACT_STATUS_Signed_MIN                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_Signed_MAX                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_Signed_MEAN                       NaN         NaN
# CC_NAME_CONTRACT_STATUS_Signed_SUM                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_Signed_VAR                        NaN         NaN
# CC_NAME_CONTRACT_STATUS_nan_MIN                           NaN         NaN
# CC_NAME_CONTRACT_STATUS_nan_MAX                           NaN         NaN
# CC_NAME_CONTRACT_STATUS_nan_MEAN                          NaN         NaN
# CC_NAME_CONTRACT_STATUS_nan_SUM                           NaN         NaN
# CC_NAME_CONTRACT_STATUS_nan_VAR                           NaN         NaN
# CC_COUNT                                                  NaN         NaN
#
# SK_ID_CURR                                              100004     100006  \
# TARGET                                                       0          0
# NAME_CONTRACT_TYPE                                           1          0
# CODE_GENDER                                                  1          0
# FLAG_OWN_CAR                                                 1          0
# FLAG_OWN_REALTY                                              1          1
# CNT_CHILDREN                                                 0          0
# AMT_INCOME_TOTAL                                         67500     135000
# AMT_CREDIT                                              135000     312682
# AMT_ANNUITY                                               6750    29686.5
# AMT_GOODS_PRICE                                         135000     297000
# NAME_TYPE_SUITE                                              6          6
# NAME_INCOME_TYPE                                             6          6
# NAME_EDUCATION_TYPE                                          4          4
# NAME_FAMILY_STATUS                                           3          0
# NAME_HOUSING_TYPE                                            1          1
# REGION_POPULATION_RELATIVE                            0.010032   0.008019
# DAYS_BIRTH                                              -19046     -19005
# DAYS_EMPLOYED                                             -225      -3039
# DAYS_REGISTRATION                                        -4260      -9833
# DAYS_ID_PUBLISH                                          -2531      -2437
# OWN_CAR_AGE                                                 26        NaN
# FLAG_MOBIL                                                   1          1
# FLAG_EMP_PHONE                                               1          1
# FLAG_WORK_PHONE                                              1          0
# FLAG_CONT_MOBILE                                             1          1
# FLAG_PHONE                                                   1          0
# FLAG_EMAIL                                                   0          0
# OCCUPATION_TYPE                                              8          8
# CNT_FAM_MEMBERS                                              1          2
# REGION_RATING_CLIENT                                         2          2
# REGION_RATING_CLIENT_W_CITY                                  2          2
# WEEKDAY_APPR_PROCESS_START                                   1          6
# HOUR_APPR_PROCESS_START                                      9         17
# REG_REGION_NOT_LIVE_REGION                                   0          0
# REG_REGION_NOT_WORK_REGION                                   0          0
# LIVE_REGION_NOT_WORK_REGION                                  0          0
# REG_CITY_NOT_LIVE_CITY                                       0          0
# REG_CITY_NOT_WORK_CITY                                       0          0
# LIVE_CITY_NOT_WORK_CITY                                      0          0
# ORGANIZATION_TYPE                                           11          5
# EXT_SOURCE_1                                               NaN        NaN
# EXT_SOURCE_2                                          0.555912   0.650442
# EXT_SOURCE_3                                          0.729567        NaN
# APARTMENTS_AVG                                             NaN        NaN
# BASEMENTAREA_AVG                                           NaN        NaN
# YEARS_BEGINEXPLUATATION_AVG                                NaN        NaN
# YEARS_BUILD_AVG                                            NaN        NaN
# COMMONAREA_AVG                                             NaN        NaN
# ELEVATORS_AVG                                              NaN        NaN
# ENTRANCES_AVG                                              NaN        NaN
# FLOORSMAX_AVG                                              NaN        NaN
# FLOORSMIN_AVG                                              NaN        NaN
# LANDAREA_AVG                                               NaN        NaN
# LIVINGAPARTMENTS_AVG                                       NaN        NaN
# LIVINGAREA_AVG                                             NaN        NaN
# NONLIVINGAPARTMENTS_AVG                                    NaN        NaN
# NONLIVINGAREA_AVG                                          NaN        NaN
# APARTMENTS_MODE                                            NaN        NaN
# BASEMENTAREA_MODE                                          NaN        NaN
# YEARS_BEGINEXPLUATATION_MODE                               NaN        NaN
# YEARS_BUILD_MODE                                           NaN        NaN
# COMMONAREA_MODE                                            NaN        NaN
# ELEVATORS_MODE                                             NaN        NaN
# ENTRANCES_MODE                                             NaN        NaN
# FLOORSMAX_MODE                                             NaN        NaN
# FLOORSMIN_MODE                                             NaN        NaN
# LANDAREA_MODE                                              NaN        NaN
# LIVINGAPARTMENTS_MODE                                      NaN        NaN
# LIVINGAREA_MODE                                            NaN        NaN
# NONLIVINGAPARTMENTS_MODE                                   NaN        NaN
# NONLIVINGAREA_MODE                                         NaN        NaN
# APARTMENTS_MEDI                                            NaN        NaN
# BASEMENTAREA_MEDI                                          NaN        NaN
# YEARS_BEGINEXPLUATATION_MEDI                               NaN        NaN
# YEARS_BUILD_MEDI                                           NaN        NaN
# COMMONAREA_MEDI                                            NaN        NaN
# ELEVATORS_MEDI                                             NaN        NaN
# ENTRANCES_MEDI                                             NaN        NaN
# FLOORSMAX_MEDI                                             NaN        NaN
# FLOORSMIN_MEDI                                             NaN        NaN
# LANDAREA_MEDI                                              NaN        NaN
# LIVINGAPARTMENTS_MEDI                                      NaN        NaN
# LIVINGAREA_MEDI                                            NaN        NaN
# NONLIVINGAPARTMENTS_MEDI                                   NaN        NaN
# NONLIVINGAREA_MEDI                                         NaN        NaN
# FONDKAPREMONT_MODE                                           0          0
# HOUSETYPE_MODE                                               1          1
# TOTALAREA_MODE                                             NaN        NaN
# WALLSMATERIAL_MODE                                           7          7
# EMERGENCYSTATE_MODE                                          2          2
# OBS_30_CNT_SOCIAL_CIRCLE                                     0          2
# DEF_30_CNT_SOCIAL_CIRCLE                                     0          0
# OBS_60_CNT_SOCIAL_CIRCLE                                     0          2
# DEF_60_CNT_SOCIAL_CIRCLE                                     0          0
# DAYS_LAST_PHONE_CHANGE                                    -815       -617
# FLAG_DOCUMENT_3                                              0          1
# FLAG_DOCUMENT_5                                              0          0
# FLAG_DOCUMENT_6                                              0          0
# FLAG_DOCUMENT_8                                              0          0
# FLAG_DOCUMENT_11                                             0          0
# FLAG_DOCUMENT_18                                             0          0
# AMT_REQ_CREDIT_BUREAU_HOUR                                   0        NaN
# AMT_REQ_CREDIT_BUREAU_DAY                                    0        NaN
# AMT_REQ_CREDIT_BUREAU_WEEK                                   0        NaN
# AMT_REQ_CREDIT_BUREAU_MON                                    0        NaN
# AMT_REQ_CREDIT_BUREAU_QRT                                    0        NaN
# AMT_REQ_CREDIT_BUREAU_YEAR                                   0        NaN
# TT_NULLCOUNT                                                48         56
# HOME_OWNER_TYPE                                              7          7
# OCC_TYPE_GENDER                                             26          8
# HOME_OWNER_GENDER                                            3          1
# ext_sources_mean                                      0.642739   0.650442
# ext_sources_std                                       0.122792        NaN
# annuity_income_percentage                                  0.1     0.2199
# car_to_birth_ratio                                 -0.00136512        NaN
# car_to_employ_ratio                                  -0.115556        NaN
# children_ratio                                               0          0
# credit_to_annuity_ratio                                     20    10.5328
# credit_to_goods_ratio                                        1     1.0528
# days_employed_percentage                             0.0118135   0.159905
# income_per_child                                         67500     135000
# income_per_person                                        67500      67500
# payment_rate                                              0.05  0.0949414
# phone_to_birth_ratio                                 0.0427911  0.0324651
# phone_to_employ_ratio                                  3.62222   0.203027
# ANNUITY_GROUPED                                       0.438877   0.438877
# AMT_ANNUITYOCCUPATION_TYPEmean                         26698.5    26698.5
# AMT_ANNUITYCODE_GENDER_NAME_EDUCATION_TYPEmean         27736.3    25358.4
# AMT_ANNUITYFLAG_OWN_REALTY_NAME_HOUSING_TYPEmean       27445.6    27445.6
# AMT_ANNUITYCODE_GENDER_ORGANIZATION_TYPEmean           28060.9    28608.1
# AMT_ANNUITYNAME_EDUCATION_TYPE_OCCUPATION_TYPEmean     26442.7    26442.7
# AMT_ANNUITYCODE_GENDER_NAME_EDUCATION_TYPE_OCCU...     27330.7    25506.7
# AMT_CREDITOCCUPATION_TYPEmean                           556548     556548
# AMT_CREDITCODE_GENDER_NAME_EDUCATION_TYPEmean           567925     554664
# AMT_CREDITFLAG_OWN_REALTY_NAME_HOUSING_TYPEmean         580990     580990
# AMT_CREDITCODE_GENDER_ORGANIZATION_TYPEmean             605823     615677
# AMT_CREDITNAME_EDUCATION_TYPE_OCCUPATION_TYPEmean       552190     552190
# AMT_CREDITCODE_GENDER_NAME_EDUCATION_TYPE_OCCUP...      559693     558888
# AMT_INCOME_TOTALOCCUPATION_TYPEmean                     165261     165261
# AMT_INCOME_TOTALCODE_GENDER_NAME_EDUCATION_TYPE...      177597     144545
# AMT_INCOME_TOTALFLAG_OWN_REALTY_NAME_HOUSING_TY...      170037     170037
# AMT_INCOME_TOTALCODE_GENDER_ORGANIZATION_TYPEmean       180368     174378
# AMT_INCOME_TOTALNAME_EDUCATION_TYPE_OCCUPATION_...      162113     162113
# AMT_INCOME_TOTALCODE_GENDER_NAME_EDUCATION_TYPE...      174063     145751
# AMT_REQ_CREDIT_BUREAU_YEAROCCUPATION_TYPEmean          1.91487    1.91487
# AMT_REQ_CREDIT_BUREAU_YEARCODE_GENDER_NAME_EDUC...     1.92237    2.02378
# AMT_REQ_CREDIT_BUREAU_YEARFLAG_OWN_REALTY_NAME_...     1.99506    1.99506
# AMT_REQ_CREDIT_BUREAU_YEARCODE_GENDER_ORGANIZAT...     1.73038    1.87544
# AMT_REQ_CREDIT_BUREAU_YEARNAME_EDUCATION_TYPE_O...     1.93352    1.93352
# AMT_REQ_CREDIT_BUREAU_YEARCODE_GENDER_NAME_EDUC...     1.90451    1.97182
# ...                                                        ...        ...
# INSTAL_PAYMENT_DIFF_SUM                                      0          0
# INSTAL_PAYMENT_DIFF_VAR                                      0          0
# INSTAL_DBD_MAX                                              11         77
# INSTAL_DBD_MEAN                                        7.66667     19.375
# INSTAL_DBD_SUM                                              23        310
# INSTAL_PAYMENT_PERC_MEAN                                     1          1
# INSTAL_PAYMENT_PERC_SUM                                      3         16
# INSTAL_PAYMENT_PERC_VAR                                      0          0
# INSTAL_COUNT                                                 3         16
# CC_MONTHS_BALANCE_MIN                                      NaN         -6
# CC_MONTHS_BALANCE_MAX                                      NaN         -1
# CC_MONTHS_BALANCE_MEAN                                     NaN       -3.5
# CC_MONTHS_BALANCE_SUM                                      NaN        -21
# CC_MONTHS_BALANCE_VAR                                      NaN        3.5
# CC_AMT_BALANCE_MIN                                         NaN          0
# CC_AMT_BALANCE_MAX                                         NaN          0
# CC_AMT_BALANCE_MEAN                                        NaN          0
# CC_AMT_BALANCE_SUM                                         NaN          0
# CC_AMT_BALANCE_VAR                                         NaN          0
# CC_AMT_CREDIT_LIMIT_ACTUAL_MIN                             NaN     270000
# CC_AMT_CREDIT_LIMIT_ACTUAL_MAX                             NaN     270000
# CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN                            NaN     270000
# CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                             NaN   1.62e+06
# CC_AMT_CREDIT_LIMIT_ACTUAL_VAR                             NaN          0
# CC_AMT_DRAWINGS_ATM_CURRENT_MIN                            NaN        NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_MAX                            NaN        NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_MEAN                           NaN        NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_SUM                            NaN          0
# CC_AMT_DRAWINGS_ATM_CURRENT_VAR                            NaN        NaN
# CC_AMT_DRAWINGS_CURRENT_MIN                                NaN          0
# CC_AMT_DRAWINGS_CURRENT_MAX                                NaN          0
# CC_AMT_DRAWINGS_CURRENT_MEAN                               NaN          0
# CC_AMT_DRAWINGS_CURRENT_SUM                                NaN          0
# CC_AMT_DRAWINGS_CURRENT_VAR                                NaN          0
# CC_AMT_DRAWINGS_OTHER_CURRENT_MIN                          NaN        NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_MAX                          NaN        NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN                         NaN        NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_SUM                          NaN          0
# CC_AMT_DRAWINGS_OTHER_CURRENT_VAR                          NaN        NaN
# CC_AMT_DRAWINGS_POS_CURRENT_MIN                            NaN        NaN
# CC_AMT_DRAWINGS_POS_CURRENT_MAX                            NaN        NaN
# CC_AMT_DRAWINGS_POS_CURRENT_MEAN                           NaN        NaN
# CC_AMT_DRAWINGS_POS_CURRENT_SUM                            NaN          0
# CC_AMT_DRAWINGS_POS_CURRENT_VAR                            NaN        NaN
# CC_AMT_INST_MIN_REGULARITY_MIN                             NaN          0
# CC_AMT_INST_MIN_REGULARITY_MAX                             NaN          0
# CC_AMT_INST_MIN_REGULARITY_MEAN                            NaN          0
# CC_AMT_INST_MIN_REGULARITY_SUM                             NaN          0
# CC_AMT_INST_MIN_REGULARITY_VAR                             NaN          0
# CC_AMT_PAYMENT_CURRENT_MIN                                 NaN        NaN
# CC_AMT_PAYMENT_CURRENT_MAX                                 NaN        NaN
# CC_AMT_PAYMENT_CURRENT_MEAN                                NaN        NaN
# CC_AMT_PAYMENT_CURRENT_SUM                                 NaN          0
# CC_AMT_PAYMENT_CURRENT_VAR                                 NaN        NaN
# CC_AMT_PAYMENT_TOTAL_CURRENT_MIN                           NaN          0
# CC_AMT_PAYMENT_TOTAL_CURRENT_MAX                           NaN          0
# CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN                          NaN          0
# CC_AMT_PAYMENT_TOTAL_CURRENT_SUM                           NaN          0
# CC_AMT_PAYMENT_TOTAL_CURRENT_VAR                           NaN          0
# CC_AMT_RECEIVABLE_PRINCIPAL_MIN                            NaN          0
# CC_AMT_RECEIVABLE_PRINCIPAL_MAX                            NaN          0
# CC_AMT_RECEIVABLE_PRINCIPAL_MEAN                           NaN          0
# CC_AMT_RECEIVABLE_PRINCIPAL_SUM                            NaN          0
# CC_AMT_RECEIVABLE_PRINCIPAL_VAR                            NaN          0
# CC_AMT_RECIVABLE_MIN                                       NaN          0
# CC_AMT_RECIVABLE_MAX                                       NaN          0
# CC_AMT_RECIVABLE_MEAN                                      NaN          0
# CC_AMT_RECIVABLE_SUM                                       NaN          0
# CC_AMT_RECIVABLE_VAR                                       NaN          0
# CC_AMT_TOTAL_RECEIVABLE_MIN                                NaN          0
# CC_AMT_TOTAL_RECEIVABLE_MAX                                NaN          0
# CC_AMT_TOTAL_RECEIVABLE_MEAN                               NaN          0
# CC_AMT_TOTAL_RECEIVABLE_SUM                                NaN          0
# CC_AMT_TOTAL_RECEIVABLE_VAR                                NaN          0
# CC_CNT_DRAWINGS_ATM_CURRENT_MIN                            NaN        NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_MAX                            NaN        NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_MEAN                           NaN        NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_SUM                            NaN          0
# CC_CNT_DRAWINGS_ATM_CURRENT_VAR                            NaN        NaN
# CC_CNT_DRAWINGS_CURRENT_MIN                                NaN          0
# CC_CNT_DRAWINGS_CURRENT_MAX                                NaN          0
# CC_CNT_DRAWINGS_CURRENT_MEAN                               NaN          0
# CC_CNT_DRAWINGS_CURRENT_SUM                                NaN          0
# CC_CNT_DRAWINGS_CURRENT_VAR                                NaN          0
# CC_CNT_DRAWINGS_OTHER_CURRENT_MIN                          NaN        NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_MAX                          NaN        NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN                         NaN        NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_SUM                          NaN          0
# CC_CNT_DRAWINGS_OTHER_CURRENT_VAR                          NaN        NaN
# CC_CNT_DRAWINGS_POS_CURRENT_MIN                            NaN        NaN
# CC_CNT_DRAWINGS_POS_CURRENT_MAX                            NaN        NaN
# CC_CNT_DRAWINGS_POS_CURRENT_MEAN                           NaN        NaN
# CC_CNT_DRAWINGS_POS_CURRENT_SUM                            NaN          0
# CC_CNT_DRAWINGS_POS_CURRENT_VAR                            NaN        NaN
# CC_CNT_INSTALMENT_MATURE_CUM_MIN                           NaN          0
# CC_CNT_INSTALMENT_MATURE_CUM_MAX                           NaN          0
# CC_CNT_INSTALMENT_MATURE_CUM_MEAN                          NaN          0
# CC_CNT_INSTALMENT_MATURE_CUM_SUM                           NaN          0
# CC_CNT_INSTALMENT_MATURE_CUM_VAR                           NaN          0
# CC_SK_DPD_MIN                                              NaN          0
# CC_SK_DPD_MAX                                              NaN          0
# CC_SK_DPD_MEAN                                             NaN          0
# CC_SK_DPD_SUM                                              NaN          0
# CC_SK_DPD_VAR                                              NaN          0
# CC_SK_DPD_DEF_MIN                                          NaN          0
# CC_SK_DPD_DEF_MAX                                          NaN          0
# CC_SK_DPD_DEF_MEAN                                         NaN          0
# CC_SK_DPD_DEF_SUM                                          NaN          0
# CC_SK_DPD_DEF_VAR                                          NaN          0
# CC_NAME_CONTRACT_STATUS_Active_MIN                         NaN          1
# CC_NAME_CONTRACT_STATUS_Active_MAX                         NaN          1
# CC_NAME_CONTRACT_STATUS_Active_MEAN                        NaN          1
# CC_NAME_CONTRACT_STATUS_Active_SUM                         NaN          6
# CC_NAME_CONTRACT_STATUS_Active_VAR                         NaN          0
# CC_NAME_CONTRACT_STATUS_Approved_MIN                       NaN          0
# CC_NAME_CONTRACT_STATUS_Approved_MAX                       NaN          0
# CC_NAME_CONTRACT_STATUS_Approved_MEAN                      NaN          0
# CC_NAME_CONTRACT_STATUS_Approved_SUM                       NaN          0
# CC_NAME_CONTRACT_STATUS_Approved_VAR                       NaN          0
# CC_NAME_CONTRACT_STATUS_Completed_MIN                      NaN          0
# CC_NAME_CONTRACT_STATUS_Completed_MAX                      NaN          0
# CC_NAME_CONTRACT_STATUS_Completed_MEAN                     NaN          0
# CC_NAME_CONTRACT_STATUS_Completed_SUM                      NaN          0
# CC_NAME_CONTRACT_STATUS_Completed_VAR                      NaN          0
# CC_NAME_CONTRACT_STATUS_Demand_MIN                         NaN          0
# CC_NAME_CONTRACT_STATUS_Demand_MAX                         NaN          0
# CC_NAME_CONTRACT_STATUS_Demand_MEAN                        NaN          0
# CC_NAME_CONTRACT_STATUS_Demand_SUM                         NaN          0
# CC_NAME_CONTRACT_STATUS_Demand_VAR                         NaN          0
# CC_NAME_CONTRACT_STATUS_Refused_MIN                        NaN          0
# CC_NAME_CONTRACT_STATUS_Refused_MAX                        NaN          0
# CC_NAME_CONTRACT_STATUS_Refused_MEAN                       NaN          0
# CC_NAME_CONTRACT_STATUS_Refused_SUM                        NaN          0
# CC_NAME_CONTRACT_STATUS_Refused_VAR                        NaN          0
# CC_NAME_CONTRACT_STATUS_Sent proposal_MIN                  NaN          0
# CC_NAME_CONTRACT_STATUS_Sent proposal_MAX                  NaN          0
# CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN                 NaN          0
# CC_NAME_CONTRACT_STATUS_Sent proposal_SUM                  NaN          0
# CC_NAME_CONTRACT_STATUS_Sent proposal_VAR                  NaN          0
# CC_NAME_CONTRACT_STATUS_Signed_MIN                         NaN          0
# CC_NAME_CONTRACT_STATUS_Signed_MAX                         NaN          0
# CC_NAME_CONTRACT_STATUS_Signed_MEAN                        NaN          0
# CC_NAME_CONTRACT_STATUS_Signed_SUM                         NaN          0
# CC_NAME_CONTRACT_STATUS_Signed_VAR                         NaN          0
# CC_NAME_CONTRACT_STATUS_nan_MIN                            NaN          0
# CC_NAME_CONTRACT_STATUS_nan_MAX                            NaN          0
# CC_NAME_CONTRACT_STATUS_nan_MEAN                           NaN          0
# CC_NAME_CONTRACT_STATUS_nan_SUM                            NaN          0
# CC_NAME_CONTRACT_STATUS_nan_VAR                            NaN          0
# CC_COUNT                                                   NaN          6
#
# SK_ID_CURR                                               100007
# TARGET                                                        0
# NAME_CONTRACT_TYPE                                            0
# CODE_GENDER                                                   1
# FLAG_OWN_CAR                                                  0
# FLAG_OWN_REALTY                                               1
# CNT_CHILDREN                                                  0
# AMT_INCOME_TOTAL                                         121500
# AMT_CREDIT                                               513000
# AMT_ANNUITY                                             21865.5
# AMT_GOODS_PRICE                                          513000
# NAME_TYPE_SUITE                                               6
# NAME_INCOME_TYPE                                              6
# NAME_EDUCATION_TYPE                                           4
# NAME_FAMILY_STATUS                                            3
# NAME_HOUSING_TYPE                                             1
# REGION_POPULATION_RELATIVE                             0.028663
# DAYS_BIRTH                                               -19932
# DAYS_EMPLOYED                                             -3038
# DAYS_REGISTRATION                                         -4311
# DAYS_ID_PUBLISH                                           -3458
# OWN_CAR_AGE                                                 NaN
# ...
# YEARS_BEGINEXPLUATATION_MODE                                NaN
# YEARS_BUILD_MODE                                            NaN
# COMMONAREA_MODE                                             NaN
# ELEVATORS_MODE                                              NaN
# ENTRANCES_MODE                                              NaN
# FLOORSMAX_MODE                                              NaN
# FLOORSMIN_MODE                                              NaN
# LANDAREA_MODE                                               NaN
# LIVINGAPARTMENTS_MODE                                       NaN
# LIVINGAREA_MODE                                             NaN
# NONLIVINGAPARTMENTS_MODE                                    NaN
# NONLIVINGAREA_MODE                                          NaN
# APARTMENTS_MEDI                                             NaN
# BASEMENTAREA_MEDI                                           NaN
# YEARS_BEGINEXPLUATATION_MEDI                                NaN
# YEARS_BUILD_MEDI                                            NaN
# COMMONAREA_MEDI                                             NaN
# ELEVATORS_MEDI                                              NaN
# ENTRANCES_MEDI                                              NaN
# FLOORSMAX_MEDI                                              NaN
# FLOORSMIN_MEDI                                              NaN
# LANDAREA_MEDI                                               NaN
# LIVINGAPARTMENTS_MEDI                                       NaN
# LIVINGAREA_MEDI                                             NaN
# NONLIVINGAPARTMENTS_MEDI                                    NaN
# NONLIVINGAREA_MEDI                                          NaN
# FONDKAPREMONT_MODE                                            0
# HOUSETYPE_MODE                                                1
# TOTALAREA_MODE                                              NaN
# WALLSMATERIAL_MODE                                            7
# EMERGENCYSTATE_MODE                                           2
# OBS_30_CNT_SOCIAL_CIRCLE                                      0
# DEF_30_CNT_SOCIAL_CIRCLE                                      0
# OBS_60_CNT_SOCIAL_CIRCLE                                      0
# DEF_60_CNT_SOCIAL_CIRCLE                                      0
# DAYS_LAST_PHONE_CHANGE                                    -1106
# FLAG_DOCUMENT_3                                               0
# FLAG_DOCUMENT_5                                               0
# FLAG_DOCUMENT_6                                               0
# FLAG_DOCUMENT_8                                               1
# FLAG_DOCUMENT_11                                              0
# FLAG_DOCUMENT_18                                              0
# AMT_REQ_CREDIT_BUREAU_HOUR                                    0
# AMT_REQ_CREDIT_BUREAU_DAY                                     0
# AMT_REQ_CREDIT_BUREAU_WEEK                                    0
# AMT_REQ_CREDIT_BUREAU_MON                                     0
# AMT_REQ_CREDIT_BUREAU_QRT                                     0
# AMT_REQ_CREDIT_BUREAU_YEAR                                    0
# TT_NULLCOUNT                                                 50
# HOME_OWNER_TYPE                                               7
# OCC_TYPE_GENDER                                              21
# HOME_OWNER_GENDER                                             3
# ext_sources_mean                                       0.322738
# ext_sources_std                                             NaN
# annuity_income_percentage                              0.179963
# car_to_birth_ratio                                          NaN
# car_to_employ_ratio                                         NaN
# children_ratio                                                0
# credit_to_annuity_ratio                                 23.4616
# credit_to_goods_ratio                                         1
# days_employed_percentage                               0.152418
# income_per_child                                         121500
# income_per_person                                        121500
# payment_rate                                          0.0426228
# phone_to_birth_ratio                                  0.0554887
# phone_to_employ_ratio                                  0.364055
# ANNUITY_GROUPED                                        0.437199
# AMT_ANNUITYOCCUPATION_TYPEmean                          27886.5
# AMT_ANNUITYCODE_GENDER_NAME_EDUCATION_TYPEmean          27736.3
# AMT_ANNUITYFLAG_OWN_REALTY_NAME_HOUSING_TYPEmean        27445.6
# AMT_ANNUITYCODE_GENDER_ORGANIZATION_TYPEmean            26292.2
# AMT_ANNUITYNAME_EDUCATION_TYPE_OCCUPATION_TYPEmean      26286.6
# AMT_ANNUITYCODE_GENDER_NAME_EDUCATION_TYPE_OCCU...      27522.2
# AMT_CREDITOCCUPATION_TYPEmean                            613692
# AMT_CREDITCODE_GENDER_NAME_EDUCATION_TYPEmean            567925
# AMT_CREDITFLAG_OWN_REALTY_NAME_HOUSING_TYPEmean          580990
# AMT_CREDITCODE_GENDER_ORGANIZATION_TYPEmean              567599
# AMT_CREDITNAME_EDUCATION_TYPE_OCCUPATION_TYPEmean        574895
# AMT_CREDITCODE_GENDER_NAME_EDUCATION_TYPE_OCCUP...       562209
# AMT_INCOME_TOTALOCCUPATION_TYPEmean                      173926
# AMT_INCOME_TOTALCODE_GENDER_NAME_EDUCATION_TYPE...       177597
# AMT_INCOME_TOTALFLAG_OWN_REALTY_NAME_HOUSING_TY...       170037
# AMT_INCOME_TOTALCODE_GENDER_ORGANIZATION_TYPEmean        176220
# AMT_INCOME_TOTALNAME_EDUCATION_TYPE_OCCUPATION_...       154425
# AMT_INCOME_TOTALCODE_GENDER_NAME_EDUCATION_TYPE...       179913
# AMT_REQ_CREDIT_BUREAU_YEAROCCUPATION_TYPEmean           1.70121
# AMT_REQ_CREDIT_BUREAU_YEARCODE_GENDER_NAME_EDUC...      1.92237
# AMT_REQ_CREDIT_BUREAU_YEARFLAG_OWN_REALTY_NAME_...      1.99506
# AMT_REQ_CREDIT_BUREAU_YEARCODE_GENDER_ORGANIZAT...      1.93023
# AMT_REQ_CREDIT_BUREAU_YEARNAME_EDUCATION_TYPE_O...      1.83042
# AMT_REQ_CREDIT_BUREAU_YEARCODE_GENDER_NAME_EDUC...      1.76495
# ...                                                         ...
# INSTAL_PAYMENT_DIFF_SUM                                 29857.4
# INSTAL_PAYMENT_DIFF_VAR                             8.08483e+06
# INSTAL_DBD_MAX                                               31
# INSTAL_DBD_MEAN                                         4.59091
# INSTAL_DBD_SUM                                              303
# INSTAL_PAYMENT_PERC_MEAN                               0.954545
# INSTAL_PAYMENT_PERC_SUM                                      63
# INSTAL_PAYMENT_PERC_VAR                               0.0439954
# INSTAL_COUNT                                                 66
# CC_MONTHS_BALANCE_MIN                                       NaN
# CC_MONTHS_BALANCE_MAX                                       NaN
# CC_MONTHS_BALANCE_MEAN                                      NaN
# CC_MONTHS_BALANCE_SUM                                       NaN
# CC_MONTHS_BALANCE_VAR                                       NaN
# CC_AMT_BALANCE_MIN                                          NaN
# CC_AMT_BALANCE_MAX                                          NaN
# CC_AMT_BALANCE_MEAN                                         NaN
# CC_AMT_BALANCE_SUM                                          NaN
# CC_AMT_BALANCE_VAR                                          NaN
# CC_AMT_CREDIT_LIMIT_ACTUAL_MIN                              NaN
# CC_AMT_CREDIT_LIMIT_ACTUAL_MAX                              NaN
# CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN                             NaN
# CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                              NaN
# CC_AMT_CREDIT_LIMIT_ACTUAL_VAR                              NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_MIN                             NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_MAX                             NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_MEAN                            NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_SUM                             NaN
# CC_AMT_DRAWINGS_ATM_CURRENT_VAR                             NaN
# CC_AMT_DRAWINGS_CURRENT_MIN                                 NaN
# CC_AMT_DRAWINGS_CURRENT_MAX                                 NaN
# CC_AMT_DRAWINGS_CURRENT_MEAN                                NaN
# CC_AMT_DRAWINGS_CURRENT_SUM                                 NaN
# CC_AMT_DRAWINGS_CURRENT_VAR                                 NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_MIN                           NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_MAX                           NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN                          NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_SUM                           NaN
# CC_AMT_DRAWINGS_OTHER_CURRENT_VAR                           NaN
# CC_AMT_DRAWINGS_POS_CURRENT_MIN                             NaN
# CC_AMT_DRAWINGS_POS_CURRENT_MAX                             NaN
# CC_AMT_DRAWINGS_POS_CURRENT_MEAN                            NaN
# CC_AMT_DRAWINGS_POS_CURRENT_SUM                             NaN
# CC_AMT_DRAWINGS_POS_CURRENT_VAR                             NaN
# CC_AMT_INST_MIN_REGULARITY_MIN                              NaN
# CC_AMT_INST_MIN_REGULARITY_MAX                              NaN
# CC_AMT_INST_MIN_REGULARITY_MEAN                             NaN
# CC_AMT_INST_MIN_REGULARITY_SUM                              NaN
# CC_AMT_INST_MIN_REGULARITY_VAR                              NaN
# CC_AMT_PAYMENT_CURRENT_MIN                                  NaN
# CC_AMT_PAYMENT_CURRENT_MAX                                  NaN
# CC_AMT_PAYMENT_CURRENT_MEAN                                 NaN
# CC_AMT_PAYMENT_CURRENT_SUM                                  NaN
# CC_AMT_PAYMENT_CURRENT_VAR                                  NaN
# CC_AMT_PAYMENT_TOTAL_CURRENT_MIN                            NaN
# CC_AMT_PAYMENT_TOTAL_CURRENT_MAX                            NaN
# CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN                           NaN
# CC_AMT_PAYMENT_TOTAL_CURRENT_SUM                            NaN
# CC_AMT_PAYMENT_TOTAL_CURRENT_VAR                            NaN
# CC_AMT_RECEIVABLE_PRINCIPAL_MIN                             NaN
# CC_AMT_RECEIVABLE_PRINCIPAL_MAX                             NaN
# CC_AMT_RECEIVABLE_PRINCIPAL_MEAN                            NaN
# CC_AMT_RECEIVABLE_PRINCIPAL_SUM                             NaN
# CC_AMT_RECEIVABLE_PRINCIPAL_VAR                             NaN
# CC_AMT_RECIVABLE_MIN                                        NaN
# CC_AMT_RECIVABLE_MAX                                        NaN
# CC_AMT_RECIVABLE_MEAN                                       NaN
# CC_AMT_RECIVABLE_SUM                                        NaN
# CC_AMT_RECIVABLE_VAR                                        NaN
# CC_AMT_TOTAL_RECEIVABLE_MIN                                 NaN
# CC_AMT_TOTAL_RECEIVABLE_MAX                                 NaN
# CC_AMT_TOTAL_RECEIVABLE_MEAN                                NaN
# CC_AMT_TOTAL_RECEIVABLE_SUM                                 NaN
# CC_AMT_TOTAL_RECEIVABLE_VAR                                 NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_MIN                             NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_MAX                             NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_MEAN                            NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_SUM                             NaN
# CC_CNT_DRAWINGS_ATM_CURRENT_VAR                             NaN
# CC_CNT_DRAWINGS_CURRENT_MIN                                 NaN
# CC_CNT_DRAWINGS_CURRENT_MAX                                 NaN
# CC_CNT_DRAWINGS_CURRENT_MEAN                                NaN
# CC_CNT_DRAWINGS_CURRENT_SUM                                 NaN
# CC_CNT_DRAWINGS_CURRENT_VAR                                 NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_MIN                           NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_MAX                           NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN                          NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_SUM                           NaN
# CC_CNT_DRAWINGS_OTHER_CURRENT_VAR                           NaN
# CC_CNT_DRAWINGS_POS_CURRENT_MIN                             NaN
# CC_CNT_DRAWINGS_POS_CURRENT_MAX                             NaN
# CC_CNT_DRAWINGS_POS_CURRENT_MEAN                            NaN
# CC_CNT_DRAWINGS_POS_CURRENT_SUM                             NaN
# CC_CNT_DRAWINGS_POS_CURRENT_VAR                             NaN
# CC_CNT_INSTALMENT_MATURE_CUM_MIN                            NaN
# CC_CNT_INSTALMENT_MATURE_CUM_MAX                            NaN
# CC_CNT_INSTALMENT_MATURE_CUM_MEAN                           NaN
# CC_CNT_INSTALMENT_MATURE_CUM_SUM                            NaN
# CC_CNT_INSTALMENT_MATURE_CUM_VAR                            NaN
# CC_SK_DPD_MIN                                               NaN
# CC_SK_DPD_MAX                                               NaN
# CC_SK_DPD_MEAN                                              NaN
# CC_SK_DPD_SUM                                               NaN
# CC_SK_DPD_VAR                                               NaN
# CC_SK_DPD_DEF_MIN                                           NaN
# CC_SK_DPD_DEF_MAX                                           NaN
# CC_SK_DPD_DEF_MEAN                                          NaN
# CC_SK_DPD_DEF_SUM                                           NaN
# CC_SK_DPD_DEF_VAR                                           NaN
# CC_NAME_CONTRACT_STATUS_Active_MIN                          NaN
# CC_NAME_CONTRACT_STATUS_Active_MAX                          NaN
# CC_NAME_CONTRACT_STATUS_Active_MEAN                         NaN
# CC_NAME_CONTRACT_STATUS_Active_SUM                          NaN
# CC_NAME_CONTRACT_STATUS_Active_VAR                          NaN
# CC_NAME_CONTRACT_STATUS_Approved_MIN                        NaN
# CC_NAME_CONTRACT_STATUS_Approved_MAX                        NaN
# CC_NAME_CONTRACT_STATUS_Approved_MEAN                       NaN
# CC_NAME_CONTRACT_STATUS_Approved_SUM                        NaN
# CC_NAME_CONTRACT_STATUS_Approved_VAR                        NaN
# CC_NAME_CONTRACT_STATUS_Completed_MIN                       NaN
# CC_NAME_CONTRACT_STATUS_Completed_MAX                       NaN
# CC_NAME_CONTRACT_STATUS_Completed_MEAN                      NaN
# CC_NAME_CONTRACT_STATUS_Completed_SUM                       NaN
# CC_NAME_CONTRACT_STATUS_Completed_VAR                       NaN
# CC_NAME_CONTRACT_STATUS_Demand_MIN                          NaN
# CC_NAME_CONTRACT_STATUS_Demand_MAX                          NaN
# CC_NAME_CONTRACT_STATUS_Demand_MEAN                         NaN
# CC_NAME_CONTRACT_STATUS_Demand_SUM                          NaN
# CC_NAME_CONTRACT_STATUS_Demand_VAR                          NaN
# CC_NAME_CONTRACT_STATUS_Refused_MIN                         NaN
# CC_NAME_CONTRACT_STATUS_Refused_MAX                         NaN
# CC_NAME_CONTRACT_STATUS_Refused_MEAN                        NaN
# CC_NAME_CONTRACT_STATUS_Refused_SUM                         NaN
# CC_NAME_CONTRACT_STATUS_Refused_VAR                         NaN
# CC_NAME_CONTRACT_STATUS_Sent proposal_MIN                   NaN
# CC_NAME_CONTRACT_STATUS_Sent proposal_MAX                   NaN
# CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN                  NaN
# CC_NAME_CONTRACT_STATUS_Sent proposal_SUM                   NaN
# CC_NAME_CONTRACT_STATUS_Sent proposal_VAR                   NaN
# CC_NAME_CONTRACT_STATUS_Signed_MIN                          NaN
# CC_NAME_CONTRACT_STATUS_Signed_MAX                          NaN
# CC_NAME_CONTRACT_STATUS_Signed_MEAN                         NaN
# CC_NAME_CONTRACT_STATUS_Signed_SUM                          NaN
# CC_NAME_CONTRACT_STATUS_Signed_VAR                          NaN
# CC_NAME_CONTRACT_STATUS_nan_MIN                             NaN
# CC_NAME_CONTRACT_STATUS_nan_MAX                             NaN
# CC_NAME_CONTRACT_STATUS_nan_MEAN                            NaN
# CC_NAME_CONTRACT_STATUS_nan_SUM                             NaN
# CC_NAME_CONTRACT_STATUS_nan_VAR                             NaN
# CC_COUNT                                                    NaN
#
# [552 rows x 5 columns]

# %%
    params = {'objective':'binary',
            'metric':'auc',
            'boosting':'gbdt', 
            'num_leaves':40,  
            'max_depth':8,  #6
            'learning_rate':0.02, 
            'subsample_for_bin':200000, 
            'class_weight':None, 
            'min_child_samples':60, #40
            'subsample':0.9, 
            'reg_lambda':10.0,  #10
            'reg_alpha':10.0,   ###
            'min_data_in_leaf':1000,    ###
            'predict_contrib':True, 
            'subsample_freq':0, 
            'colsample_bytree':0.75,  #0.85
            'num_threads':3}

    sub_preds = np.zeros_like(test.TARGET, dtype=float)
    oof_preds = np.zeros_like(y, dtype=float)
    cv = KFold(n_splits=4, shuffle=True, random_state=42)
    for trn_idx, val_idx in cv.split(X, y):
        X_train, X_val = X.iloc[trn_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[trn_idx], y.iloc[val_idx]
    
        trainDS = lgb.Dataset(X_train, label=y_train.values)
        valDS = lgb.Dataset(X_val, label=y_val.values, reference=trainDS)
        
        evalnums = {}
        lmod = lgb.train(params, trainDS, num_boost_round=1400, early_stopping_rounds=50,
            valid_sets=[trainDS, valDS], evals_result=evalnums, verbose_eval=20)
        
        oof_preds[val_idx] = lmod.predict(X_val)
        sub_preds += lmod.predict(X_test.values)/cv.n_splits 
    roc_auc_score(y, oof_preds)
# Out:
# /usr/local/lib/python2.7/dist-packages/lightgbm/basic.py:685: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 50 rounds.
# [20]	training's auc: 0.757419	valid_1's auc: 0.743745
# [40]	training's auc: 0.764103	valid_1's auc: 0.747303
# [60]	training's auc: 0.769642	valid_1's auc: 0.750529
# [80]	training's auc: 0.774697	valid_1's auc: 0.753746
# [100]	training's auc: 0.779529	valid_1's auc: 0.756764
# [120]	training's auc: 0.784136	valid_1's auc: 0.759835
# [140]	training's auc: 0.788549	valid_1's auc: 0.762587
# [160]	training's auc: 0.792513	valid_1's auc: 0.765065
# [180]	training's auc: 0.796147	valid_1's auc: 0.767111
# [200]	training's auc: 0.799234	valid_1's auc: 0.768707
# [220]	training's auc: 0.802152	valid_1's auc: 0.770142
# [240]	training's auc: 0.804678	valid_1's auc: 0.771262
# [260]	training's auc: 0.807139	valid_1's auc: 0.772344
# [280]	training's auc: 0.809425	valid_1's auc: 0.773278
# [300]	training's auc: 0.811529	valid_1's auc: 0.773979
# [320]	training's auc: 0.813539	valid_1's auc: 0.774793
# [340]	training's auc: 0.815521	valid_1's auc: 0.775459
# [360]	training's auc: 0.817363	valid_1's auc: 0.776016
# [380]	training's auc: 0.819096	valid_1's auc: 0.776516
# [400]	training's auc: 0.820735	valid_1's auc: 0.77707
# [420]	training's auc: 0.822495	valid_1's auc: 0.777457
# [440]	training's auc: 0.824131	valid_1's auc: 0.777843
# [460]	training's auc: 0.825712	valid_1's auc: 0.778262
# [480]	training's auc: 0.82735	valid_1's auc: 0.778501
# [500]	training's auc: 0.828906	valid_1's auc: 0.778812
# [520]	training's auc: 0.830553	valid_1's auc: 0.779125
# [540]	training's auc: 0.831974	valid_1's auc: 0.779361
# [560]	training's auc: 0.833367	valid_1's auc: 0.77958
# [580]	training's auc: 0.834868	valid_1's auc: 0.779851
# [600]	training's auc: 0.836242	valid_1's auc: 0.780039
# [620]	training's auc: 0.837682	valid_1's auc: 0.780269
# [640]	training's auc: 0.839005	valid_1's auc: 0.780398
# [660]	training's auc: 0.840336	valid_1's auc: 0.780588
# [680]	training's auc: 0.84179	valid_1's auc: 0.780738
# [700]	training's auc: 0.843016	valid_1's auc: 0.780908
# [720]	training's auc: 0.844195	valid_1's auc: 0.781067
# [740]	training's auc: 0.845365	valid_1's auc: 0.781219
# [760]	training's auc: 0.846588	valid_1's auc: 0.781279
# [780]	training's auc: 0.847749	valid_1's auc: 0.781328
# [800]	training's auc: 0.848966	valid_1's auc: 0.781502
# [820]	training's auc: 0.85021	valid_1's auc: 0.781625
# [840]	training's auc: 0.85137	valid_1's auc: 0.78169
# [860]	training's auc: 0.852492	valid_1's auc: 0.781766
# [880]	training's auc: 0.853608	valid_1's auc: 0.78189
# [900]	training's auc: 0.854789	valid_1's auc: 0.782
# [920]	training's auc: 0.85592	valid_1's auc: 0.782108
# [940]	training's auc: 0.857008	valid_1's auc: 0.78217
# [960]	training's auc: 0.858163	valid_1's auc: 0.782232
# [980]	training's auc: 0.859222	valid_1's auc: 0.782388
# [1000]	training's auc: 0.860264	valid_1's auc: 0.78249
# [1020]	training's auc: 0.861277	valid_1's auc: 0.782599
# [1040]	training's auc: 0.862299	valid_1's auc: 0.782626
# [1060]	training's auc: 0.863302	valid_1's auc: 0.782724
# [1080]	training's auc: 0.86429	valid_1's auc: 0.782781
# [1100]	training's auc: 0.865286	valid_1's auc: 0.782804
# [1120]	training's auc: 0.866292	valid_1's auc: 0.782834
# [1140]	training's auc: 0.86728	valid_1's auc: 0.782874
# [1160]	training's auc: 0.8682	valid_1's auc: 0.782923
# [1180]	training's auc: 0.869168	valid_1's auc: 0.782935
# [1200]	training's auc: 0.870178	valid_1's auc: 0.782993
# [1220]	training's auc: 0.871138	valid_1's auc: 0.78297
# [1240]	training's auc: 0.872058	valid_1's auc: 0.782995
# [1260]	training's auc: 0.872948	valid_1's auc: 0.783019
# [1280]	training's auc: 0.873877	valid_1's auc: 0.782997
# [1300]	training's auc: 0.874834	valid_1's auc: 0.783052
# [1320]	training's auc: 0.875725	valid_1's auc: 0.783032
# [1340]	training's auc: 0.876726	valid_1's auc: 0.783014
# Early stopping, best iteration is:
# [1303]	training's auc: 0.874986	valid_1's auc: 0.783065
# Training until validation scores don't improve for 50 rounds.
# [20]	training's auc: 0.756733	valid_1's auc: 0.74092
# [40]	training's auc: 0.763472	valid_1's auc: 0.747157
# [60]	training's auc: 0.768767	valid_1's auc: 0.751118
# [80]	training's auc: 0.773568	valid_1's auc: 0.754261
# [100]	training's auc: 0.77862	valid_1's auc: 0.757711
# [120]	training's auc: 0.783393	valid_1's auc: 0.760965
# [140]	training's auc: 0.787694	valid_1's auc: 0.763784
# [160]	training's auc: 0.791797	valid_1's auc: 0.76644
# [180]	training's auc: 0.795338	valid_1's auc: 0.768552
# [200]	training's auc: 0.798612	valid_1's auc: 0.770475
# [220]	training's auc: 0.801499	valid_1's auc: 0.772047
# [240]	training's auc: 0.804162	valid_1's auc: 0.773365
# [260]	training's auc: 0.806534	valid_1's auc: 0.774541
# [280]	training's auc: 0.808689	valid_1's auc: 0.775471
# [300]	training's auc: 0.810845	valid_1's auc: 0.776367
# [320]	training's auc: 0.812851	valid_1's auc: 0.777153
# [340]	training's auc: 0.814729	valid_1's auc: 0.777914
# [360]	training's auc: 0.816563	valid_1's auc: 0.778555
# [380]	training's auc: 0.81829	valid_1's auc: 0.77918
# [400]	training's auc: 0.820049	valid_1's auc: 0.779699
# [420]	training's auc: 0.821627	valid_1's auc: 0.78015
# [440]	training's auc: 0.823263	valid_1's auc: 0.780631
# [460]	training's auc: 0.824817	valid_1's auc: 0.78104
# [480]	training's auc: 0.826342	valid_1's auc: 0.781344
# [500]	training's auc: 0.827808	valid_1's auc: 0.781692
# [520]	training's auc: 0.829338	valid_1's auc: 0.781984
# [540]	training's auc: 0.830793	valid_1's auc: 0.782255
# [560]	training's auc: 0.832211	valid_1's auc: 0.782466
# [580]	training's auc: 0.833567	valid_1's auc: 0.782757
# [600]	training's auc: 0.834964	valid_1's auc: 0.783022
# [620]	training's auc: 0.836283	valid_1's auc: 0.783216
# [640]	training's auc: 0.83761	valid_1's auc: 0.783385
# [660]	training's auc: 0.838915	valid_1's auc: 0.783561
# [680]	training's auc: 0.840225	valid_1's auc: 0.78372
# [700]	training's auc: 0.841627	valid_1's auc: 0.783972
# [720]	training's auc: 0.842837	valid_1's auc: 0.784073
# [740]	training's auc: 0.844145	valid_1's auc: 0.784262
# [760]	training's auc: 0.845362	valid_1's auc: 0.784442
# [780]	training's auc: 0.846576	valid_1's auc: 0.784653
# [800]	training's auc: 0.847697	valid_1's auc: 0.784752
# [820]	training's auc: 0.848936	valid_1's auc: 0.784859
# [840]	training's auc: 0.850105	valid_1's auc: 0.78495
# [860]	training's auc: 0.851286	valid_1's auc: 0.785033
# [880]	training's auc: 0.852405	valid_1's auc: 0.785115
# [900]	training's auc: 0.853489	valid_1's auc: 0.785187
# [920]	training's auc: 0.854535	valid_1's auc: 0.785267
# [940]	training's auc: 0.855721	valid_1's auc: 0.785318
# [960]	training's auc: 0.856794	valid_1's auc: 0.785364
# [980]	training's auc: 0.857865	valid_1's auc: 0.785419
# [1000]	training's auc: 0.859069	valid_1's auc: 0.78544
# [1020]	training's auc: 0.860084	valid_1's auc: 0.785467
# [1040]	training's auc: 0.861083	valid_1's auc: 0.78555
# [1060]	training's auc: 0.862075	valid_1's auc: 0.785701
# [1080]	training's auc: 0.863065	valid_1's auc: 0.785764
# [1100]	training's auc: 0.864063	valid_1's auc: 0.785771
# [1120]	training's auc: 0.865098	valid_1's auc: 0.785807
# [1140]	training's auc: 0.866075	valid_1's auc: 0.785923
# [1160]	training's auc: 0.867023	valid_1's auc: 0.785988
# [1180]	training's auc: 0.867977	valid_1's auc: 0.786051
# [1200]	training's auc: 0.868951	valid_1's auc: 0.786096
# [1220]	training's auc: 0.869997	valid_1's auc: 0.786114
# [1240]	training's auc: 0.870909	valid_1's auc: 0.786171
# [1260]	training's auc: 0.871806	valid_1's auc: 0.786191
# [1280]	training's auc: 0.872827	valid_1's auc: 0.786182
# [1300]	training's auc: 0.873737	valid_1's auc: 0.786229
# [1320]	training's auc: 0.874723	valid_1's auc: 0.786254
# [1340]	training's auc: 0.875648	valid_1's auc: 0.78631
# [1360]	training's auc: 0.876445	valid_1's auc: 0.786395
# [1380]	training's auc: 0.87744	valid_1's auc: 0.786418
# [1400]	training's auc: 0.878184	valid_1's auc: 0.786455
# Did not meet early stopping. Best iteration is:
# [1400]	training's auc: 0.878184	valid_1's auc: 0.786455
# Training until validation scores don't improve for 50 rounds.
# [20]	training's auc: 0.757008	valid_1's auc: 0.746963
# [40]	training's auc: 0.763521	valid_1's auc: 0.751404
# [60]	training's auc: 0.768515	valid_1's auc: 0.754463
# [80]	training's auc: 0.773105	valid_1's auc: 0.757659
# [100]	training's auc: 0.778118	valid_1's auc: 0.761244
# [120]	training's auc: 0.78262	valid_1's auc: 0.764355
# [140]	training's auc: 0.786827	valid_1's auc: 0.767033
# [160]	training's auc: 0.790891	valid_1's auc: 0.769717
# [180]	training's auc: 0.794387	valid_1's auc: 0.772052
# [200]	training's auc: 0.797481	valid_1's auc: 0.773914
# [220]	training's auc: 0.800349	valid_1's auc: 0.775267
# [240]	training's auc: 0.802964	valid_1's auc: 0.77661
# [260]	training's auc: 0.805338	valid_1's auc: 0.777743
# [280]	training's auc: 0.807594	valid_1's auc: 0.778667
# [300]	training's auc: 0.809633	valid_1's auc: 0.779408
# [320]	training's auc: 0.811597	valid_1's auc: 0.780058
# [340]	training's auc: 0.813437	valid_1's auc: 0.780719
# [360]	training's auc: 0.815265	valid_1's auc: 0.781241
# [380]	training's auc: 0.817025	valid_1's auc: 0.781704
# [400]	training's auc: 0.818799	valid_1's auc: 0.782275
# [420]	training's auc: 0.820474	valid_1's auc: 0.782656
# [440]	training's auc: 0.822103	valid_1's auc: 0.783072
# [460]	training's auc: 0.823652	valid_1's auc: 0.783416
# [480]	training's auc: 0.825208	valid_1's auc: 0.783711
# [500]	training's auc: 0.826663	valid_1's auc: 0.783991
# [520]	training's auc: 0.828214	valid_1's auc: 0.784339
# [540]	training's auc: 0.82966	valid_1's auc: 0.784641
# [560]	training's auc: 0.831059	valid_1's auc: 0.784917
# [580]	training's auc: 0.832388	valid_1's auc: 0.785091
# [600]	training's auc: 0.833715	valid_1's auc: 0.785262
# [620]	training's auc: 0.835019	valid_1's auc: 0.785441
# [640]	training's auc: 0.836314	valid_1's auc: 0.785604
# [660]	training's auc: 0.837617	valid_1's auc: 0.785804
# [680]	training's auc: 0.838962	valid_1's auc: 0.785968
# [700]	training's auc: 0.840237	valid_1's auc: 0.786236
# [720]	training's auc: 0.841453	valid_1's auc: 0.786377
# [740]	training's auc: 0.842809	valid_1's auc: 0.786551
# [760]	training's auc: 0.84401	valid_1's auc: 0.786736
# [780]	training's auc: 0.845219	valid_1's auc: 0.786848
# [800]	training's auc: 0.846477	valid_1's auc: 0.787054
# [820]	training's auc: 0.8477	valid_1's auc: 0.787136
# [840]	training's auc: 0.848836	valid_1's auc: 0.787287
# [860]	training's auc: 0.850087	valid_1's auc: 0.7874
# [880]	training's auc: 0.851259	valid_1's auc: 0.787482
# [900]	training's auc: 0.85235	valid_1's auc: 0.787554
# [920]	training's auc: 0.853495	valid_1's auc: 0.787686
# [940]	training's auc: 0.854612	valid_1's auc: 0.787739
# [960]	training's auc: 0.855735	valid_1's auc: 0.787885
# [980]	training's auc: 0.856761	valid_1's auc: 0.7879
# [1000]	training's auc: 0.857826	valid_1's auc: 0.788019
# [1020]	training's auc: 0.858824	valid_1's auc: 0.788074
# [1040]	training's auc: 0.859727	valid_1's auc: 0.78813
# [1060]	training's auc: 0.860794	valid_1's auc: 0.788159
# [1080]	training's auc: 0.861816	valid_1's auc: 0.788239
# [1100]	training's auc: 0.862817	valid_1's auc: 0.788365
# [1120]	training's auc: 0.863793	valid_1's auc: 0.788426
# [1140]	training's auc: 0.864767	valid_1's auc: 0.788457
# [1160]	training's auc: 0.865787	valid_1's auc: 0.788488
# [1180]	training's auc: 0.866672	valid_1's auc: 0.788507
# [1200]	training's auc: 0.867682	valid_1's auc: 0.788542
# [1220]	training's auc: 0.868641	valid_1's auc: 0.788593
# [1240]	training's auc: 0.869577	valid_1's auc: 0.7886
# [1260]	training's auc: 0.870515	valid_1's auc: 0.788648
# [1280]	training's auc: 0.871498	valid_1's auc: 0.788668
# [1300]	training's auc: 0.872459	valid_1's auc: 0.788704
# [1320]	training's auc: 0.873312	valid_1's auc: 0.788754
# [1340]	training's auc: 0.874166	valid_1's auc: 0.788729
# [1360]	training's auc: 0.875037	valid_1's auc: 0.788718
# Early stopping, best iteration is:
# [1323]	training's auc: 0.873434	valid_1's auc: 0.788765
# Training until validation scores don't improve for 50 rounds.
# [20]	training's auc: 0.755252	valid_1's auc: 0.750049
# [40]	training's auc: 0.761926	valid_1's auc: 0.755485
# [60]	training's auc: 0.767494	valid_1's auc: 0.759719
# [80]	training's auc: 0.77236	valid_1's auc: 0.762968
# [100]	training's auc: 0.777442	valid_1's auc: 0.766435
# [120]	training's auc: 0.782199	valid_1's auc: 0.76957
# [140]	training's auc: 0.786471	valid_1's auc: 0.772143
# [160]	training's auc: 0.790488	valid_1's auc: 0.77467
# [180]	training's auc: 0.793864	valid_1's auc: 0.776597
# [200]	training's auc: 0.797057	valid_1's auc: 0.778357
# [220]	training's auc: 0.799971	valid_1's auc: 0.779816
# [240]	training's auc: 0.802638	valid_1's auc: 0.781096
# [260]	training's auc: 0.805103	valid_1's auc: 0.782276
# [280]	training's auc: 0.807369	valid_1's auc: 0.783269
# [300]	training's auc: 0.80939	valid_1's auc: 0.78409
# [320]	training's auc: 0.811394	valid_1's auc: 0.784795
# [340]	training's auc: 0.81333	valid_1's auc: 0.785458
# [360]	training's auc: 0.815154	valid_1's auc: 0.786001
# [380]	training's auc: 0.816965	valid_1's auc: 0.786557
# [400]	training's auc: 0.818749	valid_1's auc: 0.787083
# [420]	training's auc: 0.82045	valid_1's auc: 0.787483
# [440]	training's auc: 0.822087	valid_1's auc: 0.787809
# [460]	training's auc: 0.82367	valid_1's auc: 0.788181
# [480]	training's auc: 0.825208	valid_1's auc: 0.788538
# [500]	training's auc: 0.826755	valid_1's auc: 0.788817
# [520]	training's auc: 0.828272	valid_1's auc: 0.789135
# [540]	training's auc: 0.829673	valid_1's auc: 0.789394
# [560]	training's auc: 0.831179	valid_1's auc: 0.789688
# [580]	training's auc: 0.832757	valid_1's auc: 0.789917
# [600]	training's auc: 0.834186	valid_1's auc: 0.790079
# [620]	training's auc: 0.835588	valid_1's auc: 0.790268
# [640]	training's auc: 0.836906	valid_1's auc: 0.790408
# [660]	training's auc: 0.8382	valid_1's auc: 0.790641
# [680]	training's auc: 0.83953	valid_1's auc: 0.790843
# [700]	training's auc: 0.840829	valid_1's auc: 0.790953
# [720]	training's auc: 0.842072	valid_1's auc: 0.791123
# [740]	training's auc: 0.843395	valid_1's auc: 0.791349
# [760]	training's auc: 0.844635	valid_1's auc: 0.791527
# [780]	training's auc: 0.845785	valid_1's auc: 0.79154
# [800]	training's auc: 0.846927	valid_1's auc: 0.791642
# [820]	training's auc: 0.848177	valid_1's auc: 0.791716
# [840]	training's auc: 0.849243	valid_1's auc: 0.791773
# [860]	training's auc: 0.850288	valid_1's auc: 0.791891
# [880]	training's auc: 0.851476	valid_1's auc: 0.791935
# [900]	training's auc: 0.852608	valid_1's auc: 0.792001
# [920]	training's auc: 0.853633	valid_1's auc: 0.792061
# [940]	training's auc: 0.854755	valid_1's auc: 0.792125
# [960]	training's auc: 0.855771	valid_1's auc: 0.792228
# [980]	training's auc: 0.856884	valid_1's auc: 0.792283
# [1000]	training's auc: 0.85796	valid_1's auc: 0.792343
# [1020]	training's auc: 0.858982	valid_1's auc: 0.792421
# [1040]	training's auc: 0.859951	valid_1's auc: 0.79246
# [1060]	training's auc: 0.86097	valid_1's auc: 0.79245
# [1080]	training's auc: 0.862	valid_1's auc: 0.792482
# [1100]	training's auc: 0.862979	valid_1's auc: 0.792556
# [1120]	training's auc: 0.863974	valid_1's auc: 0.79253
# [1140]	training's auc: 0.864991	valid_1's auc: 0.792583
# [1160]	training's auc: 0.865942	valid_1's auc: 0.792581
# [1180]	training's auc: 0.866868	valid_1's auc: 0.792594
# [1200]	training's auc: 0.867687	valid_1's auc: 0.792565
# [1220]	training's auc: 0.868703	valid_1's auc: 0.792548
# Early stopping, best iteration is:
# [1173]	training's auc: 0.866519	valid_1's auc: 0.792607
# 0.7876058250469338

# %%
sub = pd.read_csv('sample_submission.csv')
sub['TARGET'] = np.around(sub_preds, 4)
sub.reset_index()
sub.to_csv('sub.csv', index=False)

# %%
sub.head()
# Out:
#    SK_ID_CURR  TARGET
# 0      100001  0.0347
# 1      100005  0.1316
# 2      100013  0.0328
# 3      100028  0.0427
# 4      100038  0.1307
